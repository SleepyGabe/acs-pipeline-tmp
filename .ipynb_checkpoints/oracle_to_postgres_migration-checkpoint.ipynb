# %% [markdown]
# # Oracle ➜ Postgres Table Migration
#
# This notebook migrates **400+ tables** from an Oracle database to a Postgres database by
# reproducing the following flow for every table in the configured list:
#
# 1. **Dump** the entire table (DDL + data) from the source Oracle DB into an Oracle-flavoured `.sql` file.
# 2. **Convert** that Oracle SQL file into a Postgres-flavoured `.sql` file (syntax conversion).
# 3. **Load** the converted Postgres SQL file into the target Postgres DB table.
#
# **Architecture**
# ```
#  ┌────────────┐   1. dump    ┌──────────────┐   2. convert   ┌────────────────┐   3. load   ┌────────────┐
#  │  Oracle DB │ ───────────► │ oracle/*.sql │ ─────────────► │ postgres/*.sql │ ──────────► │ Postgres DB│
#  └────────────┘              └──────────────┘                └────────────────┘             └────────────┘
# ```
#
# **Notes**
# - Connection details live in plain variables in the *Configuration* cell (no widgets).
# - Replace the placeholder values / `TABLE_NAMES` list with your real values. Prefer pulling
#   secrets from `dbutils.secrets` rather than hard-coding passwords (an example is shown, commented out).

# %% [markdown]
# ## 0. Install drivers
# `python-oracledb` (thin mode, no Oracle client needed) for the source and `psycopg2` for the target.

# %%
# %pip install oracledb psycopg2-binary
# %restart_python

# %% [markdown]
# ## 1. Configuration — connection details & table list (NO WIDGETS)

# %%
import os

# ----------------------------------------------------------------------------
# Oracle (SOURCE) connection details
#   Each value falls back to the literal below, but can be overridden by an
#   environment variable of the same name. That's what lets the Docker / Jupyter
#   stack point the notebook at the local containers without editing this cell.
# ----------------------------------------------------------------------------
ORACLE_HOST = os.getenv("ORACLE_HOST", "oracle-host.example.com")
ORACLE_PORT = int(os.getenv("ORACLE_PORT", "1521"))
ORACLE_SERVICE_NAME = os.getenv("ORACLE_SERVICE_NAME", "ORCLPDB1")   # use service name ...
ORACLE_SID = os.getenv("ORACLE_SID") or None                          # ... OR sid (leave one of them None)
ORACLE_USER = os.getenv("ORACLE_USER", "oracle_user")
ORACLE_PASSWORD = os.getenv("ORACLE_PASSWORD", "oracle_password")    # e.g. dbutils.secrets.get("scope", "oracle_pw")
ORACLE_SCHEMA = os.getenv("ORACLE_SCHEMA", "ORACLE_USER")            # schema that owns the tables (often == user, uppercase)

# ----------------------------------------------------------------------------
# Postgres (TARGET) connection details
# ----------------------------------------------------------------------------
PG_HOST = os.getenv("PG_HOST", "postgres-host.example.com")
PG_PORT = int(os.getenv("PG_PORT", "5432"))
PG_DATABASE = os.getenv("PG_DATABASE", "target_db")
PG_USER = os.getenv("PG_USER", "postgres_user")
PG_PASSWORD = os.getenv("PG_PASSWORD", "postgres_password")          # e.g. dbutils.secrets.get("scope", "pg_pw")
PG_SCHEMA = os.getenv("PG_SCHEMA", "public")                          # target schema in Postgres
PG_SSLMODE = os.getenv("PG_SSLMODE", "prefer")                        # disable | allow | prefer | require | verify-ca | verify-full

# ----------------------------------------------------------------------------
# Migration behaviour
# ----------------------------------------------------------------------------
WORK_DIR = os.getenv("WORK_DIR", "/dbfs/tmp/ora2pg")                 # where the .sql dump files are written
ORACLE_DUMP_DIR = os.path.join(WORK_DIR, "oracle")
POSTGRES_DUMP_DIR = os.path.join(WORK_DIR, "postgres")

BATCH_SIZE = 5_000                          # rows fetched per batch from Oracle
MAX_PARALLEL_TABLES = 8                      # how many tables to migrate concurrently (thread pool).
                                            # Each worker uses its own Oracle + Postgres connection,
                                            # so keep this <= the connection limits on BOTH databases.
                                            # Set to 1 for fully sequential migration.
# How to handle the target table on the Postgres side:
#   "recreate" — DROP (CASCADE) + CREATE from the Oracle DDL, then load. Runs ALL the structural
#                passes below (constraints/indexes/identity/sequences/FKs). Full migration. (default)
#   "truncate" — table must ALREADY EXIST. TRUNCATE it, then load data only. Skips CREATE and ALL
#                structural passes (your schema already has them). Use for "replace the data".
#   "append"   — table must ALREADY EXIST. Load data only (no drop/truncate/create). Skips ALL
#                structural passes. Use for "add data to what's there" (no dedup — may duplicate).
LOAD_MODE = "recreate"

CONTINUE_ON_ERROR = True                    # keep migrating remaining tables if one fails
KEEP_SQL_FILES = True                       # keep intermediate .sql files for auditing

# Constraint / index migration (second pass). Only applied when LOAD_MODE == "recreate".
MIGRATE_PK_UNIQUE_CHECK = True              # add PRIMARY KEY / UNIQUE / CHECK constraints
MIGRATE_INDEXES = True                      # re-create non-constraint indexes
MIGRATE_FOREIGN_KEYS = True                 # add FOREIGN KEYs (applied last, after all tables load)
MIGRATE_SEQUENCES = True                    # re-create standalone Oracle sequences in Postgres
MIGRATE_IDENTITY_COLUMNS = True             # convert Oracle IDENTITY columns to Postgres IDENTITY

# Load ordering.
RESPECT_LOAD_ORDER = False                  # True  = load tables exactly in TABLE_NAMES order
                                            # False = auto-sort by FK dependency (parents first)

# ----------------------------------------------------------------------------
# Example of sourcing secrets instead of hard-coding (recommended):
# ----------------------------------------------------------------------------
# ORACLE_PASSWORD = dbutils.secrets.get(scope="migration", key="oracle_password")
# PG_PASSWORD     = dbutils.secrets.get(scope="migration", key="pg_password")

# %% [markdown]
# ### Table list (400+ tables)
# Provide the table names as an array of strings. Two options are shown — pick one.

# %%
# Option A — explicit, hard-coded list of table names.
TABLE_NAMES = [
    "ACS_BACKUP_LIST",
    "ACS_EXTRACT",
    "ACS_EXTRACT_HISTORY",
    "ACS_EXTRACT_SUMM",
    "ACS_OP",
    "ACS_TRAN_TYPE",
    "ACS_TRANSACTION",
    "AGENCY_COMPENS_RATE",
    "AGENT",
    "AGENT_ASSIGNMENT",
    "AGENT_BANK",
    "AGENT_CDPA",
    "AGENT_CDPA_TRAN",
    "AGENT_COMMISSION",
    "AGENT_COMMISSION_STAGING",
    "AGENT_COMPENS_ELIG_AGENT_TYPE",
    "AGENT_COMPENS_ELIGIBILITY",
    "AGENT_COMPENS_ELIGIBILITY_NEW",
    "AGENT_CUMM_INCM",
    "AGENT_CUMM_INCM_DTL",
    "AGENT_CUMM_INCM_DTL_HIST",
    "AGENT_CUMM_TAX",
    "AGENT_CUMM_TAX_DTL",
    "AGENT_CUMM_TAX_DTL_HIST",
    "AGENT_DELTA",
    "AGENT_DISC",
    "AGENT_DIVISION",
    "AGENT_FORWARDED_BAL_CURR",
    "AGENT_FORWARDED_BAL_DTL",
    "AGENT_FORWARDED_BAL_DTL_IN",
    "AGENT_FORWARDED_BAL_SUMMARY",
    "AGENT_GA",
    "AGENT_GA_DETAIL",
    "AGENT_GA_DETAIL_NEW",
    "AGENT_HIERARCHY",
    "AGENT_HIERARCHY_APPOINT",
    "AGENT_HIERARCHY_CURRENT",
    "AGENT_HIERARCHY_MONTHLY",
    "AGENT_HIERARCHY_PREV",
    "AGENT_HIERARCHY_TEMP",
    "AGENT_HISTORICAL_HIERARCHY",
    "AGENT_JUM_AUDIT_TRAIL",
    "AGENT_LICENSE",
    "AGENT_LICENSE_NEW",
    "AGENT_MOVE_TYPE",
    "AGENT_MOVEMENT",
    "AGENT_MOVEMENT_AUM_FIX",
    "AGENT_MOVEMENT_DELETED",
    "AGENT_MOVEMENT_FORPROCESSING",
    "AGENT_MOVEMENT_PENDING",
    "AGENT_MOVEMENT_TEMP",
    "AGENT_MOVEMENT_TEMP_CUR",
    "AGENT_MOVEMENT_TOUPDATE",
    "AGENT_MOVEMENT_TREETEMP",
    "AGENT_MOVEMENT_VALIDATION",
    "AGENT_NAP",
    "AGENT_NAP_BACK",
    "AGENT_NEW",
    "AGENT_PAY_STAGE_IN",
    "AGENT_PAY_TRAN_CURR",
    "AGENT_PAY_TRAN_DTL",
    "AGENT_PAY_TRAN_DTL_HIST",
    "AGENT_PAY_TRAN_DTL_INVISTI",
    "AGENT_PAY_TRAN_SUMMARY",
    "AGENT_PAYOUT",
    "AGENT_PAYOUT_HELD",
    "AGENT_PERSONAL_INCOME",
    "AGENT_PREDISB",
    "AGENT_PREV",
    "AGENT_QTY_FACTOR",
    "AGENT_QTY_FACTOR_NEW",
    "AGENT_RECOMPENS_ELIGIBILITY",
    "AGENT_REGION",
    "AGENT_RELATIONSHIP",
    "AGENT_RELATIONSHIP_JUM",
    "AGENT_RELATIONSHIP_LIST",
    "AGENT_RELATIONSHIP_TEST",
    "AGENT_RELATIONSHIP_TYPE",
    "AGENT_SAVING_LVLUP",
    "AGENT_SAVING_PLAN",
    "AGENT_SAVING_PLAN_CAP",
    "AGENT_SAVING_PLAN_NEW",
    "AGENT_SAVING_PLAN_TRAN",
    "AGENT_SCHED_DEDUCTION",
    "AGENT_STATUS",
    "AGENT_SUSPENSION",
    "AGENT_SYO",
    "AGENT_TAGS",
    "AGENT_TAGS_STG",
    "AGENT_TAX_DTL",
    "AGENT_TAX_DTL_HIST",
    "AGENT_TAX_SUMMARY",
    "AGENT_TAX_SUMMARY_HIST",
    "AGENT_TAX_TAG",
    "AGENT_TEAM",
    "AGENT_TO_SYNC",
    "AGENT_TYPE",
    "AGENT_UPLINE_DATAMART",
    "AGENT_UPLINE_MISMATCHES",
    "AGENT_UPLINE_VALIDATION_LOG",
    "AGENT_WHTAX",
    "APC_EMP_REVIEWER",
    "API_CHANGE_TAB",
    "API_CHANGE_TAB_ANN",
    "APPROVAL_APC_AG_DTL",
    "APPROVAL_APC_EMP_DTL",
    "APPROVAL_BANK_DTL",
    "APPROVAL_REQUEST",
    "APPROVAL_TRAN_TYPE",
    "APPROVAL_TRANSACTION",
    "AREA",
    "AUM_LIST",
    "AUTO_CREDIT_SUMMARY",
    "AUTOCREDIT_ACCOUNT",
    "AUTOCREDIT_DISB",
    "AUTOCREDIT_DISB_DTL",
    "AUTOCREDIT_EMPLOYEE",
    "AUTOCREDIT_TRAN",
    "BANK_ACCOUNT_HISTORY",
    "BANK_ACCOUNT_STAGING",
    "BANK_PARTNERS",
    "BANK_TPD",
    "BOUNCED_CHECK",
    "BRANCH",
    "BRANCH_CEB",
    "BRANCH_IDSS",
    "BREAKAWAY_DEMOTIONS",
    "BREAKAWAY_PROMOTIONS",
    "CALENDAR",
    "CHECK_PAYMENT",
    "CLAWBACK",
    "CLIENT",
    "CLIENT_ADDRESS",
    "CLIENT_OTHER_INFO",
    "CLIENT_OTHER_INFO_HISTORY",
    "CLIENT_OTHER_INFO_STAGING",
    "COMBI_TAB",
    "COMM_DEPOSITED",
    "COMM_DEPOSITED_STAGING",
    "COMM_INCLUDE",
    "COMMCURSOR",
    "COMMISSION",
    "COMMISSION_DMTM",
    "COMMISSION_TEMP",
    "COMMISSION_TEMP_GMI",
    "COMMISSION_TPD",
    "COMPANY_SAVING_PLAN_CAP",
    "COMPENS_APE_HURDLE",
    "COMPENS_AUTO_DED_EXTRACT",
    "COMPENS_CRED",
    "COMPENS_CRED_INSTALLMENT",
    "COMPENS_CRED_MOVEMENT",
    "COMPENS_CRED_PAYT",
    "COMPENS_CRED_RECURR_MOVEMNT",
    "COMPENS_DA_REQ",
    "COMPENS_DED",
    "COMPENS_DED_INSTALLMENT",
    "COMPENS_DED_MOVEMENT",
    "COMPENS_DED_PAYT",
    "COMPENS_DED_RECURR_MOVEMNT",
    "COMPENS_MATRIX",
    "COMPENS_MATRIX_ERROR_LOG",
    "COMPENS_MATRIX_FORRO",
    "COMPENS_MATRIX_HIST",
    "COMPENS_MATRIX_IMPACT",
    "COMPENS_MATRIX_NOT_INSERTED",
    "COMPENS_MATRIX_SELLOUT",
    "COMPENS_MATRIX_TEMP",
    "COMPENS_MISC_CRED",
    "COMPENS_MISC_DED",
    "COMPENS_RATE_COMPPROD",
    "COMPENS_RATE_GAO",
    "COMPENS_RATE_IMDT_DLINE",
    "COMPENS_RATE_LEADPROD",
    "COMPENS_RATE_NUM_FACTOR",
    "COMPENS_RATE_PERSIST_GRP",
    "COMPENS_RATE_QTR_NAP",
    "COMPENS_RATE_RO",
    "COMPENS_RATE_TYPEPROD",
    "COMPENS_RATE_YRSERVICE",
    "COMPENS_RECURR_CRED",
    "COMPENS_RECURR_DED",
    "COMPENS_SCHEME",
    "COMPENS_TAB_AGENT",
    "COMPENS_TAB_AGENT_HISTORY",
    "COMPENS_TAB_ANNUAL_DTL",
    "COMPENS_TAB_ANNUAL_SUMM",
    "COMPENS_TAB_BMUM_NAP",
    "COMPENS_TAB_MP",
    "COMPENS_TAB_NAP",
    "COMPENS_TAB_NAP_ANN",
    "COMPENS_TAB_QTOTAL",
    "COMPENS_TAB_RATES",
    "COMPENS_TAB_RECRUIT",
    "COMPENS_TAB_SPARAM",
    "COMPENS_TYPE",
    "COMPENS_TYPE_AGENT_TYPE",
    "COMPENS_TYPE_CATEGORY",
    "COMPENS_TYPE_CLASS",
    "COMPENS_TYPE_DIST_CHANNEL",
    "COMPENS_TYPE_GRP",
    "COMPENS_TYPE_SCHEME",
    "COMPENS_YTDNAP_HURDLE",
    "CONTRACT_TYPE",
    "CONTRACT_TYPE_ELIG",
    "CUT_OFF_SCHED",
    "CUT_OFF_SCHED_BCKP",
    "DELETE_AGENT_MOVEMENT",
    "DELIMITED_FILE_LIST",
    "DELIMITED_FILE_VALIDATION",
    "DEPARTMENT",
    "DEPT_SERVICE",
    "DISBURSING_BANK",
    "DISTRIBUTION_CHANNEL",
    "DMPATPNS",
    "DOMAIN",
    "EXTRACT_LIST",
    "EXTRACT_LIST_TEST",
    "EXTRACT_PROCESS_ERROR",
    "FEATURE_CONTROL",
    "FIN_MANUAL_PAYMENT",
    "FIN_PAYOUT_SUMMARY",
    "FROM_SIRWILL",
    "GET_MANPOWER_REQUEST",
    "GL_ACCT",
    "GL_TRAN_DTL",
    "GL_TRAN_DTL_HIST",
    "GL_TRAN_DTL_POLREP",
    "GL_TRAN_DTL_RPT",
    "GL_TRAN_DTL_TERMINATED",
    "GL_TRAN_DTL_TPD",
    "GL_TRAN_SUMMARY",
    "GL_TRAN_SUMMARY_BKP",
    "GL_TRAN_SUMMARY_POLREP",
    "GMI_TEST",
    "GROSS_INCOME",
    "GROSS_YTD",
    "GROUP_SCHED",
    "HASH_SUMMARY",
    "HASH_SUMMARY_HISTORY",
    "HASH_SUMMARY_OPTIMIZATION",
    "HISTORICAL_DATA",
    "HYPERLINK",
    "HYPERLINK_HIERARCHY",
    "INORGANI_ORC",
    "INORGANIC_ADJUSTMENTS",
    "INORGANIC_DISBURSE",
    "INORGANIC_ENROLLEES",
    "INORGANIC_MP_DTL",
    "INORGANIC_NAP_DTL",
    "INORGANIC_PACKAGES",
    "INORGANIC_QUALIFIERS",
    "INORGANIC_TARGETS",
    "JAVA",
    "JAVA_CLASS",
    "KILL_SWITCH",
    "LETTER_OF_INSTRUCTION",
    "LVL_UP_QUALIFIER",
    "MANPOWER_OF",
    "MANPOWER_SOURCE",
    "MANUAL_PAYMENT",
    "MANUAL_PAYMENT_BACK",
    "MD_APPLICATIONS",
    "MIGRATION_AGENT_TIN_NO",
    "MIGRATION_FINAL_TAB",
    "MIGRATION_PAYOUT_DTL",
    "MIGRATION_PAYOUT_SUMMARY",
    "MIGRATION_PREMIUM_RCVD",
    "MO_COMPENS_MATRIX_ORC",
    "MODEL_TYPE",
    "NEW_AGENTS",
    "NEW_AGENTS_TEST",
    "NOMANAGER",
    "ORC_FYO",
    "ORPHAN_SYO",
    "PAYOUT_DTL",
    "PAYOUT_SUMMARY",
    "PAYROLL_SUMMARY",
    "PERSISTENCY",
    "PLAN",
    "PO",
    "PO_REL",
    "POLICY",
    "POLICY_BREAKAWAY",
    "POLICY_BREAKAWAY_TEST",
    "POLICY_DELIVERY_RECEIPT",
    "POLICY_EXTENSION",
    "POLICY_REPLACEMENT",
    "POLICY_REPLACEMENT_BCK",
    "POLICY_REPLACEMENT_REF",
    "POLICY_RIDER",
    "PREMIUM_RCVD",
    "PROCESS",
    "PROCESS_DEPENDENCY",
    "PROCESS_DURATION",
    "PROCESS_ERROR_LOG",
    "PROCESS_LOG",
    "PRODFIX_AGENT_SCHED_DEDUCTION",
    "PRODUCTION",
    "PRODUCTION_BACKUP",
    "PRODUCTION_SUMMARY",
    "PRODUCTION_UNIT",
    "PRUACE_ADJUSTMENTS",
    "PRUACE_CC_DTL",
    "PRUACE_DISBURSE",
    "PRUACE_DISBURSE_BK",
    "PRUACE_ENROLLEES",
    "PRUACE_NAP_DTL",
    "PRUACE_PACKAGES",
    "PRUACE_QUALIFIERS",
    "PRUACE_TARGETS",
    "QUALITY_FACTOR",
    "REF_SCHED",
    "REPORT_UI",
    "REVERSAL_CODE",
    "RIMON_AGENT",
    "RIMON_AGENT_DOWNLINES",
    "RIMON_AGENT_RELATIONSHIP",
    "RIMON_AGENT_TAGS",
    "RIMON_FEATURE_CONTROL",
    "RIMON_HIERARCHY_TAB",
    "RIMON_SOA_SUMMARY",
    "RMA_CONTRACT_TYPE",
    "RMA_NEW_AGENTS",
    "RMA_TAG_TYPE",
    "RO_TEMP_TABLE",
    "ROLE",
    "ROLE_SERVICE",
    "SAVINGSFUND_STG",
    "SBS_BASE_DATA",
    "SBS_BASE_DATA_KOA",
    "SELLOUT_AGREEMENTS",
    "SELLOUT_ENROLLEES",
    "SERVICE",
    "SIGNATORY",
    "SOA_BALANCE_FORWARDED",
    "SOA_BALANCE_FORWARDED_BK",
    "SOA_BONUS_DTL",
    "SOA_BONUS_DTL_BK",
    "SOA_COMMISSION_DTL",
    "SOA_COMMISSION_DTL_BK",
    "SOA_CRED_TO_BPI",
    "SOA_CRED_TO_BPI_BK",
    "SOA_GA_OVERRIDE_DTL",
    "SOA_GA_OVERRIDE_DTL_BK",
    "SOA_HOLD_BONUS_DTL",
    "SOA_HOLD_BONUS_DTL_BK",
    "SOA_HOLD_COMMISSION_DTL",
    "SOA_HOLD_COMMISSION_DTL_BK",
    "SOA_HOLD_GA_OVERRIDE_DTL",
    "SOA_HOLD_GA_OVERRIDE_DTL_BK",
    "SOA_HOLD_OVERRIDE_DTL",
    "SOA_HOLD_OVERRIDE_DTL_BK",
    "SOA_HOLD_OVERRIDE_SELLOUT",
    "SOA_HOLD_OVERRIDE_XSELLOUT",
    "SOA_LIST",
    "SOA_LIST_BK",
    "SOA_LIST_ORIG",
    "SOA_LISTBACKUP",
    "SOA_MISC_ADJUSTMENTS",
    "SOA_MISC_ADJUSTMENTS_BK",
    "SOA_MISC_CR_DTL",
    "SOA_MISC_CR_DTL_BK",
    "SOA_MISC_DR_DTL",
    "SOA_MISC_DR_DTL_BK",
    "SOA_MULTIPLE_SUSPENSION",
    "SOA_MULTIPLE_SUSPENSION_BK",
    "SOA_NOT_DEDUCTED",
    "SOA_NOT_DEDUCTED_BK",
    "SOA_OVERRIDE_DTL",
    "SOA_OVERRIDE_DTL_BK",
    "SOA_OVERRIDE_SELLOUT",
    "SOA_OVERRIDE_XSELLOUT",
    "SOA_POLICY_REVERSAL",
    "SOA_POLICY_REVERSAL_BK",
    "SOA_POLREP",
    "SOA_POLREP_BK",
    "SOA_SUMMARY",
    "SOA_TAB_PARAM",
    "SOA_TPD_POLREP",
    "SOA_TPD_POLREPREF",
    "SOA_TPD_SUMM",
    "SOA_YTD",
    "SOA_YTD_BK",
    "SPLIT_COMMISSION",
    "SUMMARY_REPORTS_CURRENT",
    "SUMMARY_REPORTS_SAVINGS",
    "SUPER_EXTRACT_DTL",
    "SUPER_EXTRACT_SUMM",
    "SUSPENDED_PAYOUT",
    "SUSPENSION_MONITORING",
    "SYS_AUDIT_TRAIL",
    "SYS_ERROR",
    "SYS_PARAMETER",
    "SYS_REF",
    "SYS_REF_TABLE",
    "SYS_USER",
    "TAB_CANCELLATIONS",
    "TAB_REVERSAL",
    "TAG_TYPE",
    "TAX",
    "TAX_UPGRADE",
    "TEMP_AGENT_CODEERROR",
    "TEMP_ERROR_FINDER",
    "TEMP_JUMERROR",
    "TEMP_LR_HIERARCHY",
    "TEMP_TABLE",
    "TEMP_TRANNO",
    "TEST",
    "TEST_AGENT_TAGS",
    "TEST_AGENTS",
    "TMP_AGU_CALLERS",
    "TMP_AGU_RUNTIME_AUDIT",
    "TMP_UPLINE_COMPARE",
    "TOAD_PLAN_SQL",
    "TOAD_PLAN_TABLE",
    "TRANSACTION",
    "TRANSACTION_OLD",
    "UPLINE_TEST_CASES",
    "UPLINE_TEST_DIFFS",
    "UPLINE_TEST_RESULTS",
    "UPLINE_TEST_RESULTS_MOD",
    "UPLINE_TEST_RESULTS_ORIG",
    "USER_OBJECTS_RIMON",
    "X_TABLE_ERROR_LOG",
    "X_TABLE_ERROR_SUMMARY_LOG",
    "XAGENTASSGN_HIST",
    "XAGENTASSGN_STAGING",
    "XAGENTDEDUCTION_HIST",
    "XAGENTDEDUCTION_STAGING",
    "XAGENTPERSISTENCY_HIST",
    "XAGENTPERSISTENCY_STAGING",
    "XAPTD",
    "XBOUNCHEDCHK_HIST",
    "XBOUNCHEDCHK_STAGING",
    "XCHEQUERCPT_HIST",
    "XCHEQUERCPT_STAGING",
    "XCLIENT_HIST",
    "XCLIENT_STAGING",
    "XCOMMISSION_HIST",
    "XCOMMISSION_STAGING",
    "XCONTRACT_HIST",
    "XCONTRACT_STAGING",
    "XCONTRACTEXT_HIST",
    "XCONTRACTEXT_STAGING",
    "XCONTRACTTPD_HIST",
    "XCONTRACTTPD_STAGING",
    "XCOVERRIDER_HIST",
    "XCOVERRIDER_STAGING",
    "XGLCODES_HIST",
    "XGLCODES_STAGING",
    "XGROUPPERSISTENCY_HIST",
    "XGROUPPERSISTENCY_STAGING",
    "XMP",
    "XPOLREP_HIST",
    "XPOLREP_STAGING",
    "XPOLREPREF_HIST",
    "XPOLREPREF_STAGING",
    "XPOLREPREFTPD_HIST",
    "XPOLREPREFTPD_STAGING",
    "XPOLREPTPD_HIST",
    "XPOLREPTPD_STAGING",
    "XPOLRIDER_HIST",
    "XPOLRIDER_STAGING",
    "XPREMIUMRCVD_HIST",
    "XPREMIUMRCVD_STAGING",
    "XSAVINGPLAN_HIST",
    "XSAVINGPLAN_STAGING",
    "XSPLITCOMM_HIST",
    "XSPLITCOMM_STAGING",
    "YEAR_REFERENCE",
]

# Option B — discover every table in the Oracle schema automatically.
# Set DISCOVER_TABLES = True to ignore the list above and pull all tables in ORACLE_SCHEMA.
DISCOVER_TABLES = False

# %% [markdown]
# ## 2. Database connection helpers

# %%
import oracledb
import psycopg2


def get_oracle_connection():
    """Open a connection to the source Oracle database (python-oracledb thin mode)."""
    if ORACLE_SERVICE_NAME:
        dsn = oracledb.makedsn(ORACLE_HOST, ORACLE_PORT, service_name=ORACLE_SERVICE_NAME)
    elif ORACLE_SID:
        dsn = oracledb.makedsn(ORACLE_HOST, ORACLE_PORT, sid=ORACLE_SID)
    else:
        raise ValueError("Either ORACLE_SERVICE_NAME or ORACLE_SID must be set.")
    return oracledb.connect(user=ORACLE_USER, password=ORACLE_PASSWORD, dsn=dsn)


def get_postgres_connection():
    """Open a connection to the target Postgres database."""
    return psycopg2.connect(
        host=PG_HOST,
        port=PG_PORT,
        dbname=PG_DATABASE,
        user=PG_USER,
        password=PG_PASSWORD,
        sslmode=PG_SSLMODE,
    )


# Make sure the working directories exist.
os.makedirs(ORACLE_DUMP_DIR, exist_ok=True)
os.makedirs(POSTGRES_DUMP_DIR, exist_ok=True)
print(f"Oracle dump dir   : {ORACLE_DUMP_DIR}")
print(f"Postgres dump dir : {POSTGRES_DUMP_DIR}")
# Out:
# Oracle dump dir   : /home/jovyan/work/ora2pg/oracle
# Postgres dump dir : /home/jovyan/work/ora2pg/postgres

# %% [markdown]
# ## 3. STEP 1 — Dump an Oracle table to a DDL `.sql` file + a COPY-ready CSV
#
# For speed, data is written as a **CSV** (Postgres `COPY` format) rather than per-row
# `INSERT`s — `COPY` is dramatically faster on large tables. The `CREATE TABLE` DDL is
# written to a separate `.sql` file (built from `all_tab_columns` for accurate Oracle types)
# and is the only thing the Step 2 converter has to touch. Values are formatted directly into
# Postgres-friendly text in Python, so the data needs no SQL-literal conversion at all.

# %%
import csv
import datetime
import decimal


def _oracle_quote_ident(name: str) -> str:
    """Quote an Oracle identifier."""
    return '"' + name.replace('"', '""') + '"'


def _oracle_output_type_handler(cursor, name, default_type, size, precision, scale):
    """
    Fetch LOBs as plain values instead of locators: CLOB/NCLOB -> str, BLOB -> bytes.
    This avoids a per-row round trip per LOB and is much faster for dumping.
    """
    if default_type in (oracledb.DB_TYPE_CLOB, oracledb.DB_TYPE_NCLOB):
        return cursor.var(oracledb.DB_TYPE_LONG, arraysize=cursor.arraysize)
    if default_type == oracledb.DB_TYPE_BLOB:
        return cursor.var(oracledb.DB_TYPE_LONG_RAW, arraysize=cursor.arraysize)
    return None


def _oracle_column_type(data_type, length, precision, scale) -> str:
    """Build an Oracle column type string from all_tab_columns metadata."""
    dt = (data_type or "").upper()
    if dt in ("VARCHAR2", "VARCHAR", "NVARCHAR2", "CHAR", "NCHAR"):
        return f"{dt}({length or 4000})"
    if dt == "NUMBER":
        if precision:
            return f"NUMBER({precision},{scale or 0})"
        return "NUMBER"
    if dt.startswith("TIMESTAMP"):
        return dt  # preserve precision / WITH TIME ZONE, the converter normalises it
    if dt in ("DATE", "CLOB", "NCLOB", "BLOB", "LONG", "FLOAT", "BINARY_FLOAT",
              "BINARY_DOUBLE", "ROWID"):
        return dt
    if dt == "RAW":
        return f"RAW({length or 2000})"
    # Fallback for anything unusual.
    return "VARCHAR2(4000)"


def _build_create_table_ddl(ora_conn, table_name: str) -> str:
    """Build an Oracle CREATE TABLE statement from the data dictionary (accurate types)."""
    cur = ora_conn.cursor()
    cur.execute(
        """
        SELECT column_name, data_type, data_length, data_precision, data_scale, nullable
        FROM all_tab_columns
        WHERE owner = :owner AND table_name = :tname
        ORDER BY column_id
        """,
        owner=ORACLE_SCHEMA.upper(), tname=table_name,
    )
    cols = cur.fetchall()
    cur.close()
    if not cols:
        raise ValueError(f"No columns found for {ORACLE_SCHEMA}.{table_name}")

    col_defs = []
    for col_name, data_type, length, precision, scale, nullable in cols:
        col_type = _oracle_column_type(data_type, length, precision, scale)
        not_null = "" if nullable == "Y" else " NOT NULL"
        col_defs.append(f"    {_oracle_quote_ident(col_name)} {col_type}{not_null}")

    return (
        f"-- Oracle DDL for {ORACLE_SCHEMA}.{table_name}\n"
        f"CREATE TABLE {_oracle_quote_ident(table_name)} (\n"
        + ",\n".join(col_defs)
        + "\n);\n"
    )


def _csv_value(value):
    """Format a Python value as Postgres COPY-CSV text. None -> '' (loaded as NULL)."""
    if value is None:
        return None  # csv.writer emits an empty field; COPY ... NULL '' reads it as NULL
    if isinstance(value, datetime.datetime):
        return value.strftime("%Y-%m-%d %H:%M:%S.%f")
    if isinstance(value, datetime.date):
        return value.strftime("%Y-%m-%d")
    if isinstance(value, (bytes, bytearray)):
        return "\\x" + value.hex()           # Postgres bytea hex input (literal in CSV mode)
    if isinstance(value, bool):
        return "t" if value else "f"
    return value                              # int / float / Decimal / str — csv.writer stringifies


def dump_oracle_table(ora_conn, table_name: str):
    """
    STEP 1: Dump a single Oracle table to (DDL .sql, data .csv).
    Returns (ddl_path, csv_path). The CSV's first row is the column header.
    """
    ddl_path = os.path.join(ORACLE_DUMP_DIR, f"{table_name}.sql")
    csv_path = os.path.join(ORACLE_DUMP_DIR, f"{table_name}.csv")
    qualified = f"{_oracle_quote_ident(ORACLE_SCHEMA)}.{_oracle_quote_ident(table_name)}"

    # DDL from the dictionary (decoupled from the data cursor's LOB handler).
    with open(ddl_path, "w", encoding="utf-8") as f:
        f.write(_build_create_table_ddl(ora_conn, table_name))

    # Data as COPY-ready CSV.
    cursor = ora_conn.cursor()
    cursor.arraysize = BATCH_SIZE
    cursor.outputtypehandler = _oracle_output_type_handler
    cursor.execute(f"SELECT * FROM {qualified}")
    col_names = [c[0] for c in cursor.description]

    row_count = 0
    with open(csv_path, "w", encoding="utf-8", newline="") as cf:
        writer = csv.writer(cf, lineterminator="\n")
        writer.writerow(col_names)                      # header row
        while True:
            rows = cursor.fetchmany(BATCH_SIZE)
            if not rows:
                break
            writer.writerows([_csv_value(v) for v in row] for row in rows)
            row_count += len(rows)
    cursor.close()

    print(f"  [dump]    {table_name}: {row_count} rows -> {csv_path}")
    return ddl_path, csv_path

# %% [markdown]
# ## 4. STEP 2 — Convert Oracle `.sql` to Postgres `.sql` (syntax conversion)
#
# A line/regex based converter covering the most common Oracle ➜ Postgres differences:
# data types, function names, sequence/DUAL idioms, identifier quoting and date literals.
# Extend `_TYPE_RULES` / `_FUNC_RULES` for any project-specific syntax you hit.
#
# > **Scope note:** This is a **syntax-only, regex-based** converter — not a SQL parser/transpiler.
# > It is designed to convert the **table data dumps generated by Step 1 of this notebook**
# > (structured `CREATE TABLE` DDL + `INSERT` statements with predictable literals), which is the
# > only input it will ever receive here. It is **not** intended for arbitrary hand-written Oracle
# > SQL or PL/SQL (e.g. `CONNECT BY`, `(+)` joins, `DECODE`, `MERGE`, procedures/packages/triggers).
# > For those, use a dedicated transpiler such as `ora2pg`.

# %%
import re

# NOTE: Syntax-only converter. Input is always the Step 1 table-data dump
# (CREATE TABLE + INSERTs), never free-form Oracle SQL / PL/SQL. See the scope
# note above before extending these rules for any other use.

# Data-type rewrites (applied to DDL). Order matters — longest/most specific first.
_TYPE_RULES = [
    (re.compile(r"\bVARCHAR2\s*\(\s*(\d+)\s*(?:CHAR|BYTE)?\s*\)", re.IGNORECASE), r"VARCHAR(\1)"),
    (re.compile(r"\bVARCHAR2\b", re.IGNORECASE), "VARCHAR"),
    (re.compile(r"\bNVARCHAR2\s*\(\s*(\d+)\s*\)", re.IGNORECASE), r"VARCHAR(\1)"),
    (re.compile(r"\bNCHAR\b", re.IGNORECASE), "CHAR"),
    (re.compile(r"\bCLOB\b", re.IGNORECASE), "TEXT"),
    (re.compile(r"\bNCLOB\b", re.IGNORECASE), "TEXT"),
    (re.compile(r"\bBLOB\b", re.IGNORECASE), "BYTEA"),
    (re.compile(r"\bLONG\s+RAW\b", re.IGNORECASE), "BYTEA"),
    (re.compile(r"\bRAW\s*\(\s*\d+\s*\)", re.IGNORECASE), "BYTEA"),
    (re.compile(r"\bLONG\b", re.IGNORECASE), "TEXT"),
    # NUMBER(p,0) -> integer-ish, NUMBER(p,s) -> NUMERIC(p,s), bare NUMBER -> NUMERIC
    (re.compile(r"\bNUMBER\s*\(\s*(\d+)\s*,\s*0\s*\)", re.IGNORECASE), r"NUMERIC(\1)"),
    (re.compile(r"\bNUMBER\s*\(\s*(\d+)\s*,\s*(\d+)\s*\)", re.IGNORECASE), r"NUMERIC(\1,\2)"),
    (re.compile(r"\bNUMBER\b", re.IGNORECASE), "NUMERIC"),
    (re.compile(r"\bBINARY_DOUBLE\b", re.IGNORECASE), "DOUBLE PRECISION"),
    (re.compile(r"\bBINARY_FLOAT\b", re.IGNORECASE), "REAL"),
    (re.compile(r"\bFLOAT\b", re.IGNORECASE), "DOUBLE PRECISION"),
    # Oracle DATE carries a time component -> map to TIMESTAMP in Postgres.
    (re.compile(r"\bDATE\b", re.IGNORECASE), "TIMESTAMP"),
]

# Function / expression rewrites (applied to data + DDL).
_FUNC_RULES = [
    (re.compile(r"\bSYSDATE\b", re.IGNORECASE), "CURRENT_TIMESTAMP"),
    (re.compile(r"\bSYSTIMESTAMP\b", re.IGNORECASE), "CURRENT_TIMESTAMP"),
    (re.compile(r"\bNVL\s*\(", re.IGNORECASE), "COALESCE("),
    (re.compile(r"\bSYS_GUID\s*\(\s*\)", re.IGNORECASE), "gen_random_uuid()"),
    # Oracle string concat is the same (||) so nothing to do there.
    # FROM DUAL is meaningless in Postgres.
    (re.compile(r"\bFROM\s+DUAL\b", re.IGNORECASE), ""),
    # HEXTORAW('AABB') -> '\xAABB'  (Postgres bytea hex literal)
    (re.compile(r"HEXTORAW\s*\(\s*'([0-9A-Fa-f]*)'\s*\)"), r"'\\x\1'"),
]

# TO_DATE / TO_TIMESTAMP with the formats we emit in step 1 -> Postgres casts.
_TO_TIMESTAMP_RE = re.compile(
    r"TO_TIMESTAMP\s*\(\s*'([^']*)'\s*,\s*'[^']*'\s*\)", re.IGNORECASE
)
_TO_DATE_RE = re.compile(
    r"TO_DATE\s*\(\s*'([^']*)'\s*,\s*'[^']*'\s*\)", re.IGNORECASE
)


def _convert_line(line: str, in_ddl: bool) -> str:
    """Apply the conversion rules to a single line of SQL."""
    # Date/time literal conversions first (they contain quoted strings).
    line = _TO_TIMESTAMP_RE.sub(r"TIMESTAMP '\1'", line)
    line = _TO_DATE_RE.sub(r"DATE '\1'", line)

    # Function / expression rewrites.
    for pattern, repl in _FUNC_RULES:
        line = pattern.sub(repl, line)

    # Data-type rewrites only matter inside DDL.
    if in_ddl:
        for pattern, repl in _TYPE_RULES:
            line = pattern.sub(repl, line)

    return line


def convert_oracle_sql_to_postgres(oracle_sql_path: str, table_name: str) -> str:
    """
    STEP 2: Convert an Oracle .sql file into a Postgres .sql file.
    Returns the path to the converted file.
    """
    out_path = os.path.join(POSTGRES_DUMP_DIR, f"{table_name}.sql")

    with open(oracle_sql_path, "r", encoding="utf-8") as src, \
         open(out_path, "w", encoding="utf-8") as dst:

        dst.write(f"-- Converted from Oracle dump: {os.path.basename(oracle_sql_path)}\n")
        dst.write(f"SET search_path TO {PG_SCHEMA};\n\n")

        in_ddl = False
        for raw_line in src:
            line = raw_line

            # Track whether we are inside a CREATE TABLE block so type rules apply there.
            stripped = line.strip().upper()
            if stripped.startswith("CREATE TABLE"):
                in_ddl = True
            line = _convert_line(line, in_ddl)
            if in_ddl and ");" in line:
                in_ddl = False

            # Oracle uses "" for quoting; Postgres uses "" too, so identifiers pass through.
            dst.write(line)

    print(f"  [convert] {table_name}: {oracle_sql_path} -> {out_path}")
    return out_path


def convert_oracle_sql_text(oracle_sql_text: str) -> str:
    """
    Convert a chunk of Oracle SQL text (e.g. constraint / index DDL) to Postgres.
    Used by the constraints pass. Type rules are skipped (no column type defs here);
    function rules (NVL, SYSDATE, ...) still apply, which matters for CHECK conditions.
    """
    return "".join(_convert_line(line, in_ddl=False) for line in oracle_sql_text.splitlines(keepends=True))

# %% [markdown]
# ## 5. STEP 3 — Prepare the target per `LOAD_MODE`, then bulk-load the CSV via `COPY`
#
# `COPY` is used instead of executing per-row `INSERT`s — it streams the whole CSV into
# Postgres in one operation and is typically 10–100× faster on large tables.
#
# **`LOAD_MODE`** controls what happens to a pre-existing target table:
# - `"recreate"` (default) — DROP (CASCADE) + CREATE from the converted DDL, then load. Runs
#   the structural passes (constraints/indexes/identity/sequences/FKs).
# - `"truncate"` — table must already exist; TRUNCATE it, then load **data only** (no DDL,
#   no structural passes).
# - `"append"` — table must already exist; load **data only**, no truncate (rows are added).
#
# In the data-only modes a preflight checks the table exists and its columns cover the data.

# %%
def _split_sql_statements(sql_text: str):
    """
    Split a SQL script into individual statements on semicolons,
    ignoring semicolons that appear inside single-quoted string literals.
    """
    statements = []
    buf = []
    in_string = False
    i = 0
    n = len(sql_text)
    while i < n:
        ch = sql_text[i]
        buf.append(ch)
        if ch == "'":
            # Handle escaped '' inside a string literal.
            if in_string and i + 1 < n and sql_text[i + 1] == "'":
                buf.append(sql_text[i + 1])
                i += 2
                continue
            in_string = not in_string
        elif ch == ";" and not in_string:
            stmt = "".join(buf).strip()
            if stmt and stmt != ";":
                statements.append(stmt.rstrip(";").strip())
            buf = []
        i += 1
    tail = "".join(buf).strip()
    if tail:
        statements.append(tail.rstrip(";").strip())
    return [s for s in statements if s]


def _assert_target_ready(cur, table_name: str, csv_columns):
    """For data-only modes: verify the target table exists and has the CSV's columns."""
    cur.execute(
        "SELECT column_name FROM information_schema.columns "
        "WHERE table_schema = %s AND table_name = %s",
        (PG_SCHEMA, table_name),
    )
    existing = {r[0] for r in cur.fetchall()}
    if not existing:
        raise RuntimeError(
            f'LOAD_MODE="{LOAD_MODE}" but target table "{PG_SCHEMA}"."{table_name}" '
            f"does not exist. Create it first, or use LOAD_MODE=\"recreate\"."
        )
    missing = [c for c in csv_columns if c not in existing]
    if missing:
        raise RuntimeError(
            f'Target "{PG_SCHEMA}"."{table_name}" is missing column(s) {missing} '
            f"present in the Oracle data. Column names must match for COPY."
        )


def load_postgres_copy(pg_conn, postgres_ddl_path: str, csv_path: str, table_name: str):
    """
    STEP 3: Prepare the target table per LOAD_MODE, then bulk-load the CSV with COPY.

    LOAD_MODE:
      "recreate" — DROP (CASCADE) + CREATE from the converted DDL, then load.
      "truncate" — TRUNCATE the existing table, then load (data only).
      "append"   — load into the existing table as-is (data only).

    The CSV's first line is a header giving the column order.
    """
    cur = pg_conn.cursor()
    qualified = f'"{PG_SCHEMA}"."{table_name}"'
    try:
        if LOAD_MODE == "recreate":
            cur.execute(f"DROP TABLE IF EXISTS {qualified} CASCADE;")
            with open(postgres_ddl_path, "r", encoding="utf-8") as f:
                for stmt in _split_sql_statements(f.read()):
                    cur.execute(stmt)

        # Bulk-load the data. Read the header to pin the column order, then COPY the rest.
        with open(csv_path, "r", encoding="utf-8", newline="") as f:
            header = next(csv.reader([f.readline()]))

            if LOAD_MODE in ("truncate", "append"):
                _assert_target_ready(cur, table_name, header)
            if LOAD_MODE == "truncate":
                cur.execute(f"TRUNCATE TABLE {qualified};")

            col_list = ", ".join('"' + c.replace('"', '""') + '"' for c in header)
            copy_sql = (
                f"COPY {qualified} ({col_list}) "
                f"FROM STDIN WITH (FORMAT csv, HEADER false, NULL '')"
            )
            cur.copy_expert(copy_sql, f)      # f is now positioned just after the header
            row_count = cur.rowcount

        pg_conn.commit()
        print(f"  [load]    {table_name}: COPY {row_count} rows ({LOAD_MODE})")
    except Exception:
        pg_conn.rollback()
        raise
    finally:
        cur.close()

# %% [markdown]
# ## 5b. SECOND PASS — Primary keys, unique/check constraints, indexes & foreign keys
#
# The first pass only carries column definitions + data. This pass reads the Oracle data
# dictionary (`all_constraints`, `all_cons_columns`, `all_indexes`, `all_ind_columns`) and
# reproduces the relational structure on Postgres:
#
# - **PK / UNIQUE / CHECK** and **indexes** are applied per-table (they only reference one table).
# - **FOREIGN KEYs** are collected across all tables and applied **last**, after every table and
#   its data exist, so referential integrity doesn't fail on table/row ordering.
#
# As with the data pass, DDL is dumped Oracle-flavoured ➜ converted ➜ loaded.

# %%
def _pg_ident(name: str) -> str:
    """Quote an identifier for Postgres."""
    return '"' + name.replace('"', '""') + '"'


def _pg_qualified(table_name: str) -> str:
    return f"{_pg_ident(PG_SCHEMA)}.{_pg_ident(table_name)}"


def _table_columns(ora_conn, owner: str, table_name: str):
    """All column names for a table (used to quote identifiers in CHECK conditions)."""
    cur = ora_conn.cursor()
    cur.execute(
        """
        SELECT column_name
        FROM all_tab_columns
        WHERE owner = :owner AND table_name = :tname
        """,
        owner=owner, tname=table_name,
    )
    cols = [r[0] for r in cur.fetchall()]
    cur.close()
    return cols


# Matches: a double-quoted identifier, OR a single-quoted string literal
# (Oracle '' escaping), OR a bare identifier. Order matters so quoted regions
# are consumed whole and never rewritten.
_CHECK_TOKEN_RE = re.compile(
    r'"[^"]*"|\'(?:[^\']|\'\')*\'|[A-Za-z_][A-Za-z0-9_$#]*'
)


def _quote_check_condition(cond: str, columns) -> str:
    """
    Quote bare column identifiers in an Oracle CHECK search_condition so they
    survive Postgres' unquoted-folds-to-lowercase rule. Columns are created
    quoted/upper-case, so an unquoted ``ACTIVE`` would fold to ``active`` and
    fail with "column does not exist". String literals and already-quoted
    identifiers are left untouched.
    """
    colset = {c.upper() for c in columns}

    def repl(m):
        tok = m.group(0)
        if tok[0] in ('"', "'"):  # quoted identifier or string literal
            return tok
        if tok.upper() in colset:
            return '"' + tok.upper() + '"'
        return tok

    return _CHECK_TOKEN_RE.sub(repl, cond)


def _constraint_columns(ora_conn, owner: str, constraint_name: str):
    """Ordered column list for a given constraint."""
    cur = ora_conn.cursor()
    cur.execute(
        """
        SELECT column_name
        FROM all_cons_columns
        WHERE owner = :owner AND constraint_name = :cname
        ORDER BY position
        """,
        owner=owner, cname=constraint_name,
    )
    cols = [r[0] for r in cur.fetchall()]
    cur.close()
    return cols


def build_oracle_constraint_ddl(ora_conn, table_name: str):
    """
    Read PK / UNIQUE / CHECK constraints and indexes for a table and return
    Oracle-flavoured DDL (str). Foreign keys are intentionally excluded here.
    """
    owner = ORACLE_SCHEMA.upper()
    qualified = f'"{table_name}"'
    lines = [f"-- constraints & indexes for {table_name}"]
    table_cols = _table_columns(ora_conn, owner, table_name)

    cur = ora_conn.cursor()

    # --- PK / UNIQUE / CHECK constraints ---
    if MIGRATE_PK_UNIQUE_CHECK:
        cur.execute(
            """
            SELECT constraint_name, constraint_type, search_condition
            FROM all_constraints
            WHERE owner = :owner AND table_name = :tname
              AND constraint_type IN ('P', 'U', 'C')
              AND status = 'ENABLED'
            ORDER BY constraint_type, constraint_name
            """,
            owner=owner, tname=table_name,
        )
        for cname, ctype, search_cond in cur.fetchall():
            if ctype in ("P", "U"):
                cols = _constraint_columns(ora_conn, owner, cname)
                if not cols:
                    continue
                kind = "PRIMARY KEY" if ctype == "P" else "UNIQUE"
                col_list = ", ".join(f'"{c}"' for c in cols)
                lines.append(
                    f'ALTER TABLE {qualified} ADD CONSTRAINT "{cname}" {kind} ({col_list});'
                )
            elif ctype == "C":
                cond = (search_cond or "").strip()
                # Skip the system-generated "COL" IS NOT NULL checks (already NOT NULL in DDL).
                if not cond or re.match(r'^"?\w+"?\s+IS\s+NOT\s+NULL$', cond, re.IGNORECASE):
                    continue
                cond = _quote_check_condition(cond, table_cols)
                lines.append(
                    f'ALTER TABLE {qualified} ADD CONSTRAINT "{cname}" CHECK ({cond});'
                )

    # --- Indexes (excluding those backing PK / UNIQUE constraints) ---
    if MIGRATE_INDEXES:
        cur.execute(
            """
            SELECT index_name, uniqueness
            FROM all_indexes
            WHERE table_owner = :owner AND table_name = :tname
              AND index_type = 'NORMAL'
              AND index_name NOT IN (
                  SELECT constraint_name FROM all_constraints
                  WHERE owner = :owner AND table_name = :tname
                    AND constraint_type IN ('P', 'U')
              )
            ORDER BY index_name
            """,
            owner=owner, tname=table_name,
        )
        index_rows = cur.fetchall()
        for index_name, uniqueness in index_rows:
            icur = ora_conn.cursor()
            icur.execute(
                """
                SELECT column_name
                FROM all_ind_columns
                WHERE index_owner = :owner AND index_name = :iname
                ORDER BY column_position
                """,
                owner=owner, iname=index_name,
            )
            icols = [r[0] for r in icur.fetchall()]
            icur.close()
            if not icols:
                continue
            unique = "UNIQUE " if uniqueness == "UNIQUE" else ""
            col_list = ", ".join(f'"{c}"' for c in icols)
            lines.append(
                f'CREATE {unique}INDEX "{index_name}" ON {qualified} ({col_list});'
            )

    cur.close()
    return "\n".join(lines) + "\n"


def build_oracle_foreign_key_ddl(ora_conn, table_name: str):
    """Return Oracle-flavoured FOREIGN KEY DDL (str) for a single table."""
    owner = ORACLE_SCHEMA.upper()
    qualified = f'"{table_name}"'
    lines = []

    cur = ora_conn.cursor()
    cur.execute(
        """
        SELECT c.constraint_name, c.r_owner, c.r_constraint_name,
               c.delete_rule, rc.table_name AS ref_table
        FROM all_constraints c
        JOIN all_constraints rc
          ON rc.owner = c.r_owner AND rc.constraint_name = c.r_constraint_name
        WHERE c.owner = :owner AND c.table_name = :tname
          AND c.constraint_type = 'R' AND c.status = 'ENABLED'
        ORDER BY c.constraint_name
        """,
        owner=owner, tname=table_name,
    )
    for cname, r_owner, r_cname, delete_rule, ref_table in cur.fetchall():
        local_cols = _constraint_columns(ora_conn, owner, cname)
        ref_cols = _constraint_columns(ora_conn, r_owner, r_cname)
        if not local_cols or not ref_cols:
            continue
        local_list = ", ".join(f'"{c}"' for c in local_cols)
        ref_list = ", ".join(f'"{c}"' for c in ref_cols)
        # Referenced table is migrated into PG_SCHEMA as well.
        on_delete = ""
        if delete_rule and delete_rule.upper() in ("CASCADE", "SET NULL"):
            on_delete = f" ON DELETE {delete_rule.upper()}"
        lines.append(
            f'ALTER TABLE {qualified} ADD CONSTRAINT "{cname}" '
            f'FOREIGN KEY ({local_list}) '
            f'REFERENCES "{ref_table}" ({ref_list}){on_delete};'
        )
    cur.close()
    return "\n".join(lines)


def migrate_table_constraints(ora_conn, pg_conn, table_name: str):
    """Dump ➜ convert ➜ load PK / UNIQUE / CHECK / indexes for one table."""
    if not (MIGRATE_PK_UNIQUE_CHECK or MIGRATE_INDEXES):
        return
    oracle_ddl = build_oracle_constraint_ddl(ora_conn, table_name)
    postgres_ddl = convert_oracle_sql_text(oracle_ddl)

    ora_path = os.path.join(ORACLE_DUMP_DIR, f"{table_name}_constraints.sql")
    pg_path = os.path.join(POSTGRES_DUMP_DIR, f"{table_name}_constraints.sql")
    with open(ora_path, "w", encoding="utf-8") as f:
        f.write(oracle_ddl)
    with open(pg_path, "w", encoding="utf-8") as f:
        f.write(f"SET search_path TO {PG_SCHEMA};\n")
        f.write(postgres_ddl)

    cur = pg_conn.cursor()
    try:
        executed = 0
        for stmt in _split_sql_statements(postgres_ddl):
            cur.execute(stmt)
            executed += 1
        pg_conn.commit()
        if executed:
            print(f"  [constr]  {table_name}: applied {executed} constraint/index statements")
    except Exception:
        pg_conn.rollback()
        raise
    finally:
        cur.close()
        if not KEEP_SQL_FILES:
            os.remove(ora_path)
            os.remove(pg_path)


def migrate_foreign_keys(ora_conn, pg_conn, table_names):
    """
    Final pass: dump ➜ convert ➜ load all FOREIGN KEYs once every table exists.
    Each FK is applied independently so one bad FK doesn't abort the rest.
    """
    if not MIGRATE_FOREIGN_KEYS:
        return 0

    all_fk_lines = []
    for table_name in table_names:
        ddl = build_oracle_foreign_key_ddl(ora_conn, table_name)
        if ddl.strip():
            all_fk_lines.append(ddl)

    if not all_fk_lines:
        print("No foreign keys to migrate.")
        return 0

    oracle_ddl = "-- foreign keys (all tables)\n" + "\n".join(all_fk_lines) + "\n"
    postgres_ddl = convert_oracle_sql_text(oracle_ddl)

    ora_path = os.path.join(ORACLE_DUMP_DIR, "_foreign_keys.sql")
    pg_path = os.path.join(POSTGRES_DUMP_DIR, "_foreign_keys.sql")
    with open(ora_path, "w", encoding="utf-8") as f:
        f.write(oracle_ddl)
    with open(pg_path, "w", encoding="utf-8") as f:
        f.write(f"SET search_path TO {PG_SCHEMA};\n")
        f.write(postgres_ddl)

    applied, failed = 0, 0
    cur = pg_conn.cursor()
    for stmt in _split_sql_statements(postgres_ddl):
        try:
            cur.execute(stmt)
            pg_conn.commit()
            applied += 1
        except Exception as exc:  # noqa: BLE001
            pg_conn.rollback()
            failed += 1
            print(f"  [fk ERROR] {exc}")
    cur.close()
    print(f"Foreign keys: applied {applied}, failed {failed}")
    if not KEEP_SQL_FILES:
        os.remove(ora_path)
        os.remove(pg_path)
    return applied

# %% [markdown]
# ## 5c. THIRD PASS — Sequences & identity columns
#
# Auto-increment behaviour in Oracle comes in two shapes, both handled here:
#
# - **Standalone sequences** (`all_sequences`) ➜ Postgres `CREATE SEQUENCE`, started at the
#   sequence's current high-water value. Oracle's enormous default `MAXVALUE` (28 nines)
#   exceeds Postgres `bigint`, so it is clamped to `NO MAXVALUE` when out of range.
# - **Identity columns** (`all_tab_identity_cols`, Oracle 12c+) ➜ the column is altered to
#   `GENERATED {ALWAYS|BY DEFAULT} AS IDENTITY` *after* its data is loaded, then `RESTART WITH
#   MAX(col)+1` so future inserts don't collide with migrated rows.
#
# > Pre-12c "sequence + BEFORE INSERT trigger" auto-increment is **not** auto-detected — convert
# > those columns to identity manually or rely on the migrated standalone sequence.

# %%
# Postgres bigint bounds — Oracle sequences can exceed these.
_PG_BIGINT_MAX = 9223372036854775807
_PG_BIGINT_MIN = -9223372036854775808


def migrate_sequences(ora_conn, pg_conn):
    """Re-create every standalone Oracle sequence in Postgres (run once)."""
    if not MIGRATE_SEQUENCES:
        return 0

    cur = ora_conn.cursor()
    cur.execute(
        """
        SELECT sequence_name, min_value, max_value, increment_by,
               cycle_flag, cache_size, last_number
        FROM all_sequences
        WHERE sequence_owner = :owner
        ORDER BY sequence_name
        """,
        owner=ORACLE_SCHEMA.upper(),
    )
    rows = cur.fetchall()
    cur.close()

    if not rows:
        print("No sequences to migrate.")
        return 0

    statements = []
    for name, min_v, max_v, incr, cycle_flag, cache, last_number in rows:
        min_v = int(min_v)
        max_v = int(max_v)
        incr = int(incr or 1)
        start = int(last_number or min_v)

        minclause = f"MINVALUE {min_v}" if min_v >= _PG_BIGINT_MIN else "NO MINVALUE"
        maxclause = f"MAXVALUE {max_v}" if max_v <= _PG_BIGINT_MAX else "NO MAXVALUE"
        # Clamp the start value into the representable range as well.
        start = max(min(start, _PG_BIGINT_MAX), _PG_BIGINT_MIN)
        cacheclause = f"CACHE {int(cache)}" if cache and int(cache) > 1 else "CACHE 1"
        cycleclause = "CYCLE" if (cycle_flag or "N").upper() == "Y" else "NO CYCLE"

        statements.append(
            f'CREATE SEQUENCE IF NOT EXISTS {_pg_qualified(name)} '
            f'INCREMENT BY {incr} {minclause} {maxclause} '
            f'START WITH {start} {cacheclause} {cycleclause};'
        )

    # Dump ➜ (no conversion needed, already Postgres) ➜ load.
    sql_text = f"SET search_path TO {PG_SCHEMA};\n" + "\n".join(statements) + "\n"
    pg_path = os.path.join(POSTGRES_DUMP_DIR, "_sequences.sql")
    with open(pg_path, "w", encoding="utf-8") as f:
        f.write(sql_text)

    applied = 0
    cur = pg_conn.cursor()
    try:
        for stmt in statements:
            cur.execute(stmt)
            applied += 1
        pg_conn.commit()
    except Exception:
        pg_conn.rollback()
        raise
    finally:
        cur.close()
        if not KEEP_SQL_FILES:
            os.remove(pg_path)
    print(f"Sequences: created {applied}")
    return applied


def migrate_identity_columns(ora_conn, pg_conn, table_name: str):
    """Convert Oracle IDENTITY columns on one table to Postgres IDENTITY columns."""
    if not MIGRATE_IDENTITY_COLUMNS:
        return

    cur = ora_conn.cursor()
    cur.execute(
        """
        SELECT column_name, generation_type
        FROM all_tab_identity_cols
        WHERE owner = :owner AND table_name = :tname
        """,
        owner=ORACLE_SCHEMA.upper(), tname=table_name,
    )
    identity_cols = cur.fetchall()
    cur.close()
    if not identity_cols:
        return

    qualified = _pg_qualified(table_name)
    pgcur = pg_conn.cursor()
    try:
        for column_name, generation_type in identity_cols:
            col = _pg_ident(column_name)
            gen = "ALWAYS" if (generation_type or "").upper() == "ALWAYS" else "BY DEFAULT"

            # Find the current max so the identity sequence resumes past migrated data.
            pgcur.execute(f"SELECT COALESCE(MAX({col}), 0) FROM {qualified}")
            current_max = pgcur.fetchone()[0] or 0

            pgcur.execute(
                f"ALTER TABLE {qualified} ALTER COLUMN {col} "
                f"ADD GENERATED {gen} AS IDENTITY;"
            )
            pgcur.execute(
                f"ALTER TABLE {qualified} ALTER COLUMN {col} "
                f"RESTART WITH {int(current_max) + 1};"
            )
            print(f"  [ident]   {table_name}.{column_name}: GENERATED {gen} AS IDENTITY "
                  f"(restart {int(current_max) + 1})")
        pg_conn.commit()
    except Exception:
        pg_conn.rollback()
        raise
    finally:
        pgcur.close()

# %% [markdown]
# ## 5d. Dependency-aware load ordering
#
# Some tables must load before others (parent before child). We read the foreign-key graph
# from `all_constraints` (type `R`) — **restricted to the tables being migrated** — and
# topologically sort it so every parent loads before its children (Kahn's algorithm).
#
# Robustness details:
# - **Self-references** (a table FK'ing itself) are ignored for ordering — a single table is
#   always loadable on its own; the FK is satisfied later by the deferred FK pass.
# - **Cycles** (e.g. A→B→A) cannot be fully ordered. They are detected, logged, and broken by
#   emitting the lowest-remaining-dependency tables in a stable order; those rows rely on the
#   deferred FK pass for integrity.
# - **Deterministic**: ties broken alphabetically, so the same input always yields the same order.
# - FKs pointing at tables **outside** the migration set are ignored for ordering (we can't load
#   what we're not migrating), but are reported so you know they exist.

# %%
def build_fk_dependency_graph(ora_conn, table_names):
    """
    Build the FK dependency graph for the given tables.

    Returns (deps, external_refs) where:
      deps[child] = set(parents)  — parents that must load before `child`
                                    (self-refs removed; only in-scope parents kept)
      external_refs[child] = set(parents outside the migration set)
    """
    in_scope = {t.upper() for t in table_names}
    owner = ORACLE_SCHEMA.upper()

    deps = {t: set() for t in table_names}
    # Map uppercase -> original spelling so we preserve the caller's casing.
    canonical = {t.upper(): t for t in table_names}
    external_refs = {}

    cur = ora_conn.cursor()
    cur.execute(
        """
        SELECT c.table_name AS child_table, rc.table_name AS parent_table
        FROM all_constraints c
        JOIN all_constraints rc
          ON rc.owner = c.r_owner AND rc.constraint_name = c.r_constraint_name
        WHERE c.owner = :owner AND c.constraint_type = 'R' AND c.status = 'ENABLED'
        """,
        owner=owner,
    )
    rows = cur.fetchall()
    cur.close()

    for child_raw, parent_raw in rows:
        child_u, parent_u = child_raw.upper(), parent_raw.upper()
        if child_u not in in_scope:
            continue  # the dependent table isn't part of this migration
        if parent_u == child_u:
            continue  # self-reference — not an ordering constraint
        if parent_u in in_scope:
            deps[canonical[child_u]].add(canonical[parent_u])
        else:
            external_refs.setdefault(canonical[child_u], set()).add(parent_raw)

    return deps, external_refs


def order_tables_by_dependency(ora_conn, table_names):
    """
    Return table_names reordered so FK parents load before children (Kahn's algorithm).

    Robust to cycles: when no zero-dependency table remains, the cycle is broken by
    choosing the remaining table with the fewest unmet dependencies (ties alphabetical),
    which is logged. Output always contains exactly the input tables, once each.
    """
    deps, external_refs = build_fk_dependency_graph(ora_conn, table_names)

    if external_refs:
        print("Note: FKs referencing tables OUTSIDE the migration set (ignored for ordering):")
        for child, parents in sorted(external_refs.items()):
            print(f"  - {child} -> {', '.join(sorted(parents))}")

    # Work on a mutable copy of the dependency sets.
    remaining = {t: set(parents) for t, parents in deps.items()}
    ordered = []
    placed = set()
    cycles_broken = []

    while remaining:
        # Tables whose parents are all already placed.
        ready = sorted(t for t, parents in remaining.items() if not (parents - placed))
        if not ready:
            # Cycle (or mutual dependency): break it deterministically.
            unmet = lambda t: len(remaining[t] - placed)
            victim = sorted(remaining, key=lambda t: (unmet(t), t))[0]
            cycles_broken.append(victim)
            ready = [victim]

        for t in ready:
            ordered.append(t)
            placed.add(t)
            del remaining[t]

    if cycles_broken:
        print("WARNING: FK dependency cycle(s) detected. Order forced for these tables "
              "(they rely on the deferred FK pass for integrity):")
        for t in cycles_broken:
            print(f"  - {t}")

    return ordered


def resolve_load_order(ora_conn, table_names):
    """Apply RESPECT_LOAD_ORDER: keep the given order, or sort by FK dependency."""
    if RESPECT_LOAD_ORDER:
        print("Load order: using TABLE_NAMES order as-is (RESPECT_LOAD_ORDER=True).")
        return list(table_names)
    print("Load order: resolving FK dependencies (parents before children)...")
    ordered = order_tables_by_dependency(ora_conn, table_names)
    print(f"Load order resolved for {len(ordered)} tables.")
    return ordered

# %% [markdown]
# ## 6. Orchestration — parallel fan-out (thread pool) with bracketing sequence/FK passes
#
# Tables are migrated concurrently with a thread pool of `MAX_PARALLEL_TABLES` workers. Each
# worker runs the full per-table pipeline (dump ➜ convert ➜ COPY ➜ constraints ➜ identity)
# on its **own** Oracle + Postgres connections — the drivers are not safe to share across
# threads. The work is I/O-bound (DB + file I/O releases the GIL), so threads give real
# concurrency and overlap Oracle reads with Postgres writes across different tables.
#
# Sequences run once **before** the pool; foreign keys run once **after** it (deferred-FK
# design), so load order is irrelevant to correctness and tables can finish in any order.

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed


def discover_oracle_tables(ora_conn):
    """Return all table names owned by ORACLE_SCHEMA."""
    cur = ora_conn.cursor()
    cur.execute(
        "SELECT table_name FROM all_tables WHERE owner = :owner ORDER BY table_name",
        owner=ORACLE_SCHEMA.upper(),
    )
    names = [r[0] for r in cur.fetchall()]
    cur.close()
    return names


def migrate_one_table(table_name: str):
    """
    Full per-table pipeline on dedicated connections (safe to run in a worker thread).
    Returns (table_name, ok: bool, error: str | None, seconds: float).
    """
    t0 = datetime.datetime.now()
    ora_conn = get_oracle_connection()
    pg_conn = get_postgres_connection()
    try:
        ddl_path, csv_path = dump_oracle_table(ora_conn, table_name)        # STEP 1
        pg_ddl_path = convert_oracle_sql_to_postgres(ddl_path, table_name)  # STEP 2
        load_postgres_copy(pg_conn, pg_ddl_path, csv_path, table_name)      # STEP 3
        if LOAD_MODE == "recreate":
            # Structural passes only when we built the table; in data-only modes
            # (truncate/append) the target schema already has these.
            migrate_table_constraints(ora_conn, pg_conn, table_name)       # PK/UNIQUE/CHECK/index
            migrate_identity_columns(ora_conn, pg_conn, table_name)        # identity columns

        if not KEEP_SQL_FILES:
            for p in (ddl_path, csv_path, pg_ddl_path):
                try:
                    os.remove(p)
                except OSError:
                    pass

        elapsed = (datetime.datetime.now() - t0).total_seconds()
        return (table_name, True, None, elapsed)
    except Exception as exc:  # noqa: BLE001
        elapsed = (datetime.datetime.now() - t0).total_seconds()
        return (table_name, False, str(exc), elapsed)
    finally:
        ora_conn.close()
        pg_conn.close()


def migrate_all_tables():
    """Run the full dump ➜ convert ➜ COPY pipeline for every table, in parallel."""
    if LOAD_MODE not in ("recreate", "truncate", "append"):
        raise ValueError(f'LOAD_MODE must be "recreate", "truncate" or "append", got "{LOAD_MODE}"')

    setup_ora = get_oracle_connection()
    setup_pg = get_postgres_connection()

    try:
        table_names = discover_oracle_tables(setup_ora) if DISCOVER_TABLES else list(TABLE_NAMES)
        # Ordering is computed for logging/visibility; with parallel fan-out + deferred FKs it is
        # not required for correctness (tables may finish in any order).
        table_names = resolve_load_order(setup_ora, table_names)
        total = len(table_names)
        workers = max(1, int(MAX_PARALLEL_TABLES))
        print(f"Migrating {total} tables with {workers} parallel worker(s) [LOAD_MODE={LOAD_MODE}]\n"
              + "=" * 60)

        results = {"ok": [], "failed": []}
        start_all = datetime.datetime.now()

        # Standalone sequences: create up front (only when building schema, not in data-only modes).
        if LOAD_MODE == "recreate":
            migrate_sequences(setup_ora, setup_pg)
            print("-" * 60)

        # Parallel fan-out: each table is migrated end-to-end on its own connections.
        done = 0
        with ThreadPoolExecutor(max_workers=workers) as pool:
            futures = {pool.submit(migrate_one_table, t): t for t in table_names}
            for fut in as_completed(futures):
                table_name, ok, err, elapsed = fut.result()
                done += 1
                if ok:
                    print(f"[{done}/{total}] [done]  {table_name} in {elapsed:.1f}s")
                    results["ok"].append(table_name)
                else:
                    print(f"[{done}/{total}] [ERROR] {table_name}: {err}")
                    results["failed"].append((table_name, err))

        # FINAL PASS: foreign keys, once every table + its data exists.
        # Only when building schema; data-only modes leave existing FKs untouched.
        if LOAD_MODE == "recreate":
            print("\n" + "-" * 60)
            ok_in_order = [t for t in table_names if t in set(results["ok"])]
            migrate_foreign_keys(setup_ora, setup_pg, ok_in_order)

        total_elapsed = (datetime.datetime.now() - start_all).total_seconds()
        print("\n" + "=" * 60)
        print(f"Finished in {total_elapsed:.1f}s — "
              f"{len(results['ok'])} ok, {len(results['failed'])} failed")
        if results["failed"]:
            print("\nFailed tables:")
            for name, err in results["failed"]:
                print(f"  - {name}: {err}")
            if not CONTINUE_ON_ERROR:
                raise RuntimeError(f"{len(results['failed'])} table(s) failed to migrate")
        return results
    finally:
        setup_ora.close()
        setup_pg.close()

# %% [markdown]
# ## 7. Run the migration

# %%
results = migrate_all_tables()
# Out:
# Load order: resolving FK dependencies (parents before children)...
# Load order resolved for 471 tables.
# Migrating 471 tables with 8 parallel worker(s) [LOAD_MODE=recreate]
# ============================================================
# Sequences: created 2
# ------------------------------------------------------------
# [1/471] [ERROR] ACS_EXTRACT_HISTORY: No columns found for ORACLE_USER.ACS_EXTRACT_HISTORY
# [2/471] [ERROR] ACS_EXTRACT: No columns found for ORACLE_USER.ACS_EXTRACT
# [3/471] [ERROR] ACS_OP: No columns found for ORACLE_USER.ACS_OP
# [4/471] [ERROR] ACS_BACKUP_LIST: No columns found for ORACLE_USER.ACS_BACKUP_LIST
# [5/471] [ERROR] ACS_EXTRACT_SUMM: No columns found for ORACLE_USER.ACS_EXTRACT_SUMM
# [6/471] [ERROR] ACS_TRANSACTION: No columns found for ORACLE_USER.ACS_TRANSACTION
# [7/471] [ERROR] ACS_TRAN_TYPE: No columns found for ORACLE_USER.ACS_TRAN_TYPE
# [8/471] [ERROR] AGENCY_COMPENS_RATE: No columns found for ORACLE_USER.AGENCY_COMPENS_RATE
# [9/471] [ERROR] AGENT: No columns found for ORACLE_USER.AGENT
# [10/471] [ERROR] AGENT_ASSIGNMENT: No columns found for ORACLE_USER.AGENT_ASSIGNMENT
# [11/471] [ERROR] AGENT_CDPA: No columns found for ORACLE_USER.AGENT_CDPA
# [12/471] [ERROR] AGENT_BANK: No columns found for ORACLE_USER.AGENT_BANK
# [13/471] [ERROR] AGENT_CDPA_TRAN: No columns found for ORACLE_USER.AGENT_CDPA_TRAN
# [14/471] [ERROR] AGENT_COMMISSION: No columns found for ORACLE_USER.AGENT_COMMISSION
# [15/471] [ERROR] AGENT_COMMISSION_STAGING: No columns found for ORACLE_USER.AGENT_COMMISSION_STAGING
# [16/471] [ERROR] AGENT_COMPENS_ELIGIBILITY: No columns found for ORACLE_USER.AGENT_COMPENS_ELIGIBILITY
# [17/471] [ERROR] AGENT_COMPENS_ELIGIBILITY_NEW: No columns found for ORACLE_USER.AGENT_COMPENS_ELIGIBILITY_NEW
# [18/471] [ERROR] AGENT_COMPENS_ELIG_AGENT_TYPE: No columns found for ORACLE_USER.AGENT_COMPENS_ELIG_AGENT_TYPE
# [19/471] [ERROR] AGENT_CUMM_INCM: No columns found for ORACLE_USER.AGENT_CUMM_INCM
# [20/471] [ERROR] AGENT_CUMM_INCM_DTL: No columns found for ORACLE_USER.AGENT_CUMM_INCM_DTL
# [21/471] [ERROR] AGENT_CUMM_INCM_DTL_HIST: No columns found for ORACLE_USER.AGENT_CUMM_INCM_DTL_HIST
# [22/471] [ERROR] AGENT_CUMM_TAX: No columns found for ORACLE_USER.AGENT_CUMM_TAX
# [23/471] [ERROR] AGENT_CUMM_TAX_DTL: No columns found for ORACLE_USER.AGENT_CUMM_TAX_DTL
# [24/471] [ERROR] AGENT_CUMM_TAX_DTL_HIST: No columns found for ORACLE_USER.AGENT_CUMM_TAX_DTL_HIST
# [25/471] [ERROR] AGENT_DELTA: No columns found for ORACLE_USER.AGENT_DELTA
# [26/471] [ERROR] AGENT_DISC: No columns found for ORACLE_USER.AGENT_DISC
# [27/471] [ERROR] AGENT_DIVISION: No columns found for ORACLE_USER.AGENT_DIVISION
# [28/471] [ERROR] AGENT_FORWARDED_BAL_CURR: No columns found for ORACLE_USER.AGENT_FORWARDED_BAL_CURR
# [29/471] [ERROR] AGENT_FORWARDED_BAL_DTL: No columns found for ORACLE_USER.AGENT_FORWARDED_BAL_DTL
# [30/471] [ERROR] AGENT_FORWARDED_BAL_DTL_IN: No columns found for ORACLE_USER.AGENT_FORWARDED_BAL_DTL_IN
# [31/471] [ERROR] AGENT_FORWARDED_BAL_SUMMARY: No columns found for ORACLE_USER.AGENT_FORWARDED_BAL_SUMMARY
# [32/471] [ERROR] AGENT_GA: No columns found for ORACLE_USER.AGENT_GA
# [33/471] [ERROR] AGENT_GA_DETAIL: No columns found for ORACLE_USER.AGENT_GA_DETAIL
# [34/471] [ERROR] AGENT_GA_DETAIL_NEW: No columns found for ORACLE_USER.AGENT_GA_DETAIL_NEW
# [35/471] [ERROR] AGENT_HIERARCHY: No columns found for ORACLE_USER.AGENT_HIERARCHY
# [36/471] [ERROR] AGENT_HIERARCHY_APPOINT: No columns found for ORACLE_USER.AGENT_HIERARCHY_APPOINT
# [37/471] [ERROR] AGENT_HIERARCHY_CURRENT: No columns found for ORACLE_USER.AGENT_HIERARCHY_CURRENT
# [38/471] [ERROR] AGENT_HIERARCHY_MONTHLY: No columns found for ORACLE_USER.AGENT_HIERARCHY_MONTHLY
# [39/471] [ERROR] AGENT_HIERARCHY_PREV: No columns found for ORACLE_USER.AGENT_HIERARCHY_PREV
# [40/471] [ERROR] AGENT_HIERARCHY_TEMP: No columns found for ORACLE_USER.AGENT_HIERARCHY_TEMP
# [41/471] [ERROR] AGENT_HISTORICAL_HIERARCHY: No columns found for ORACLE_USER.AGENT_HISTORICAL_HIERARCHY
# [42/471] [ERROR] AGENT_JUM_AUDIT_TRAIL: No columns found for ORACLE_USER.AGENT_JUM_AUDIT_TRAIL
# [43/471] [ERROR] AGENT_LICENSE: No columns found for ORACLE_USER.AGENT_LICENSE
# [44/471] [ERROR] AGENT_LICENSE_NEW: No columns found for ORACLE_USER.AGENT_LICENSE_NEW
# [45/471] [ERROR] AGENT_MOVEMENT: No columns found for ORACLE_USER.AGENT_MOVEMENT
# [46/471] [ERROR] AGENT_MOVEMENT_AUM_FIX: No columns found for ORACLE_USER.AGENT_MOVEMENT_AUM_FIX
# [47/471] [ERROR] AGENT_MOVEMENT_DELETED: No columns found for ORACLE_USER.AGENT_MOVEMENT_DELETED
# [48/471] [ERROR] AGENT_MOVEMENT_FORPROCESSING: No columns found for ORACLE_USER.AGENT_MOVEMENT_FORPROCESSING
# [49/471] [ERROR] AGENT_MOVEMENT_PENDING: No columns found for ORACLE_USER.AGENT_MOVEMENT_PENDING
# [50/471] [ERROR] AGENT_MOVEMENT_TEMP: No columns found for ORACLE_USER.AGENT_MOVEMENT_TEMP
# [51/471] [ERROR] AGENT_MOVEMENT_TEMP_CUR: No columns found for ORACLE_USER.AGENT_MOVEMENT_TEMP_CUR
# [52/471] [ERROR] AGENT_MOVEMENT_TOUPDATE: No columns found for ORACLE_USER.AGENT_MOVEMENT_TOUPDATE
# [53/471] [ERROR] AGENT_MOVEMENT_TREETEMP: No columns found for ORACLE_USER.AGENT_MOVEMENT_TREETEMP
# [54/471] [ERROR] AGENT_MOVEMENT_VALIDATION: No columns found for ORACLE_USER.AGENT_MOVEMENT_VALIDATION
# [55/471] [ERROR] AGENT_MOVE_TYPE: No columns found for ORACLE_USER.AGENT_MOVE_TYPE
# [56/471] [ERROR] AGENT_NAP: No columns found for ORACLE_USER.AGENT_NAP
# [57/471] [ERROR] AGENT_NAP_BACK: No columns found for ORACLE_USER.AGENT_NAP_BACK
# [58/471] [ERROR] AGENT_NEW: No columns found for ORACLE_USER.AGENT_NEW
# [59/471] [ERROR] AGENT_PAYOUT: No columns found for ORACLE_USER.AGENT_PAYOUT
# [60/471] [ERROR] AGENT_PAYOUT_HELD: No columns found for ORACLE_USER.AGENT_PAYOUT_HELD
# [61/471] [ERROR] AGENT_PAY_STAGE_IN: No columns found for ORACLE_USER.AGENT_PAY_STAGE_IN
# [62/471] [ERROR] AGENT_PAY_TRAN_CURR: No columns found for ORACLE_USER.AGENT_PAY_TRAN_CURR
# [63/471] [ERROR] AGENT_PAY_TRAN_DTL: No columns found for ORACLE_USER.AGENT_PAY_TRAN_DTL
# [64/471] [ERROR] AGENT_PAY_TRAN_DTL_HIST: No columns found for ORACLE_USER.AGENT_PAY_TRAN_DTL_HIST
# [65/471] [ERROR] AGENT_PAY_TRAN_DTL_INVISTI: No columns found for ORACLE_USER.AGENT_PAY_TRAN_DTL_INVISTI
# [66/471] [ERROR] AGENT_PAY_TRAN_SUMMARY: No columns found for ORACLE_USER.AGENT_PAY_TRAN_SUMMARY
# [67/471] [ERROR] AGENT_PERSONAL_INCOME: No columns found for ORACLE_USER.AGENT_PERSONAL_INCOME
# [68/471] [ERROR] AGENT_PREDISB: No columns found for ORACLE_USER.AGENT_PREDISB
# [69/471] [ERROR] AGENT_PREV: No columns found for ORACLE_USER.AGENT_PREV
# [70/471] [ERROR] AGENT_QTY_FACTOR: No columns found for ORACLE_USER.AGENT_QTY_FACTOR
# [71/471] [ERROR] AGENT_QTY_FACTOR_NEW: No columns found for ORACLE_USER.AGENT_QTY_FACTOR_NEW
# [72/471] [ERROR] AGENT_RECOMPENS_ELIGIBILITY: No columns found for ORACLE_USER.AGENT_RECOMPENS_ELIGIBILITY
# [73/471] [ERROR] AGENT_REGION: No columns found for ORACLE_USER.AGENT_REGION
# [74/471] [ERROR] AGENT_RELATIONSHIP: No columns found for ORACLE_USER.AGENT_RELATIONSHIP
# [75/471] [ERROR] AGENT_RELATIONSHIP_JUM: No columns found for ORACLE_USER.AGENT_RELATIONSHIP_JUM
# [76/471] [ERROR] AGENT_RELATIONSHIP_LIST: No columns found for ORACLE_USER.AGENT_RELATIONSHIP_LIST
# [77/471] [ERROR] AGENT_RELATIONSHIP_TEST: No columns found for ORACLE_USER.AGENT_RELATIONSHIP_TEST
# [78/471] [ERROR] AGENT_RELATIONSHIP_TYPE: No columns found for ORACLE_USER.AGENT_RELATIONSHIP_TYPE
# [79/471] [ERROR] AGENT_SAVING_LVLUP: No columns found for ORACLE_USER.AGENT_SAVING_LVLUP
# [80/471] [ERROR] AGENT_SAVING_PLAN: No columns found for ORACLE_USER.AGENT_SAVING_PLAN
# [81/471] [ERROR] AGENT_SAVING_PLAN_CAP: No columns found for ORACLE_USER.AGENT_SAVING_PLAN_CAP
# [82/471] [ERROR] AGENT_SAVING_PLAN_NEW: No columns found for ORACLE_USER.AGENT_SAVING_PLAN_NEW
# [83/471] [ERROR] AGENT_SAVING_PLAN_TRAN: No columns found for ORACLE_USER.AGENT_SAVING_PLAN_TRAN
# [84/471] [ERROR] AGENT_SCHED_DEDUCTION: No columns found for ORACLE_USER.AGENT_SCHED_DEDUCTION
# [85/471] [ERROR] AGENT_STATUS: No columns found for ORACLE_USER.AGENT_STATUS
# [86/471] [ERROR] AGENT_SUSPENSION: No columns found for ORACLE_USER.AGENT_SUSPENSION
# [87/471] [ERROR] AGENT_SYO: No columns found for ORACLE_USER.AGENT_SYO
# [88/471] [ERROR] AGENT_TAGS: No columns found for ORACLE_USER.AGENT_TAGS
# [89/471] [ERROR] AGENT_TAGS_STG: No columns found for ORACLE_USER.AGENT_TAGS_STG
# [90/471] [ERROR] AGENT_TAX_DTL: No columns found for ORACLE_USER.AGENT_TAX_DTL
# [91/471] [ERROR] AGENT_TAX_DTL_HIST: No columns found for ORACLE_USER.AGENT_TAX_DTL_HIST
# [92/471] [ERROR] AGENT_TAX_SUMMARY: No columns found for ORACLE_USER.AGENT_TAX_SUMMARY
# [93/471] [ERROR] AGENT_TAX_SUMMARY_HIST: No columns found for ORACLE_USER.AGENT_TAX_SUMMARY_HIST
# [94/471] [ERROR] AGENT_TAX_TAG: No columns found for ORACLE_USER.AGENT_TAX_TAG
# [95/471] [ERROR] AGENT_TEAM: No columns found for ORACLE_USER.AGENT_TEAM
# [96/471] [ERROR] AGENT_TO_SYNC: No columns found for ORACLE_USER.AGENT_TO_SYNC
# [97/471] [ERROR] AGENT_TYPE: No columns found for ORACLE_USER.AGENT_TYPE
# [98/471] [ERROR] AGENT_UPLINE_DATAMART: No columns found for ORACLE_USER.AGENT_UPLINE_DATAMART
# [99/471] [ERROR] AGENT_UPLINE_MISMATCHES: No columns found for ORACLE_USER.AGENT_UPLINE_MISMATCHES
# [100/471] [ERROR] AGENT_UPLINE_VALIDATION_LOG: No columns found for ORACLE_USER.AGENT_UPLINE_VALIDATION_LOG
# [101/471] [ERROR] AGENT_WHTAX: No columns found for ORACLE_USER.AGENT_WHTAX
# [102/471] [ERROR] APC_EMP_REVIEWER: No columns found for ORACLE_USER.APC_EMP_REVIEWER
# [103/471] [ERROR] API_CHANGE_TAB: No columns found for ORACLE_USER.API_CHANGE_TAB
# [104/471] [ERROR] API_CHANGE_TAB_ANN: No columns found for ORACLE_USER.API_CHANGE_TAB_ANN
# [105/471] [ERROR] APPROVAL_APC_AG_DTL: No columns found for ORACLE_USER.APPROVAL_APC_AG_DTL
# [106/471] [ERROR] APPROVAL_APC_EMP_DTL: No columns found for ORACLE_USER.APPROVAL_APC_EMP_DTL
# [107/471] [ERROR] APPROVAL_BANK_DTL: No columns found for ORACLE_USER.APPROVAL_BANK_DTL
# [108/471] [ERROR] APPROVAL_REQUEST: No columns found for ORACLE_USER.APPROVAL_REQUEST
# [109/471] [ERROR] APPROVAL_TRANSACTION: No columns found for ORACLE_USER.APPROVAL_TRANSACTION
# [110/471] [ERROR] APPROVAL_TRAN_TYPE: No columns found for ORACLE_USER.APPROVAL_TRAN_TYPE
# [111/471] [ERROR] AREA: No columns found for ORACLE_USER.AREA
# [112/471] [ERROR] AUM_LIST: No columns found for ORACLE_USER.AUM_LIST
# [113/471] [ERROR] AUTOCREDIT_ACCOUNT: No columns found for ORACLE_USER.AUTOCREDIT_ACCOUNT
# [114/471] [ERROR] AUTOCREDIT_DISB: No columns found for ORACLE_USER.AUTOCREDIT_DISB
# [115/471] [ERROR] AUTOCREDIT_DISB_DTL: No columns found for ORACLE_USER.AUTOCREDIT_DISB_DTL
# [116/471] [ERROR] AUTOCREDIT_EMPLOYEE: No columns found for ORACLE_USER.AUTOCREDIT_EMPLOYEE
# [117/471] [ERROR] AUTOCREDIT_TRAN: No columns found for ORACLE_USER.AUTOCREDIT_TRAN
# [118/471] [ERROR] AUTO_CREDIT_SUMMARY: No columns found for ORACLE_USER.AUTO_CREDIT_SUMMARY
# [119/471] [ERROR] BANK_ACCOUNT_HISTORY: No columns found for ORACLE_USER.BANK_ACCOUNT_HISTORY
# [120/471] [ERROR] BANK_ACCOUNT_STAGING: No columns found for ORACLE_USER.BANK_ACCOUNT_STAGING
# [121/471] [ERROR] BANK_PARTNERS: No columns found for ORACLE_USER.BANK_PARTNERS
# [122/471] [ERROR] BANK_TPD: No columns found for ORACLE_USER.BANK_TPD
# [123/471] [ERROR] BOUNCED_CHECK: No columns found for ORACLE_USER.BOUNCED_CHECK
# [124/471] [ERROR] BRANCH: No columns found for ORACLE_USER.BRANCH
# [125/471] [ERROR] BRANCH_CEB: No columns found for ORACLE_USER.BRANCH_CEB
# [126/471] [ERROR] BRANCH_IDSS: No columns found for ORACLE_USER.BRANCH_IDSS
# [127/471] [ERROR] BREAKAWAY_DEMOTIONS: No columns found for ORACLE_USER.BREAKAWAY_DEMOTIONS
# [128/471] [ERROR] BREAKAWAY_PROMOTIONS: No columns found for ORACLE_USER.BREAKAWAY_PROMOTIONS
# [129/471] [ERROR] CALENDAR: No columns found for ORACLE_USER.CALENDAR
# [130/471] [ERROR] CHECK_PAYMENT: No columns found for ORACLE_USER.CHECK_PAYMENT
# [131/471] [ERROR] CLAWBACK: No columns found for ORACLE_USER.CLAWBACK
# [132/471] [ERROR] CLIENT: No columns found for ORACLE_USER.CLIENT
# [133/471] [ERROR] CLIENT_ADDRESS: No columns found for ORACLE_USER.CLIENT_ADDRESS
# [134/471] [ERROR] CLIENT_OTHER_INFO: No columns found for ORACLE_USER.CLIENT_OTHER_INFO
# [135/471] [ERROR] CLIENT_OTHER_INFO_HISTORY: No columns found for ORACLE_USER.CLIENT_OTHER_INFO_HISTORY
# [136/471] [ERROR] CLIENT_OTHER_INFO_STAGING: No columns found for ORACLE_USER.CLIENT_OTHER_INFO_STAGING
# [137/471] [ERROR] COMBI_TAB: No columns found for ORACLE_USER.COMBI_TAB
# [138/471] [ERROR] COMMCURSOR: No columns found for ORACLE_USER.COMMCURSOR
# [139/471] [ERROR] COMMISSION: No columns found for ORACLE_USER.COMMISSION
# [140/471] [ERROR] COMMISSION_DMTM: No columns found for ORACLE_USER.COMMISSION_DMTM
# [141/471] [ERROR] COMMISSION_TEMP: No columns found for ORACLE_USER.COMMISSION_TEMP
# [142/471] [ERROR] COMMISSION_TEMP_GMI: No columns found for ORACLE_USER.COMMISSION_TEMP_GMI
# [143/471] [ERROR] COMMISSION_TPD: No columns found for ORACLE_USER.COMMISSION_TPD
# [144/471] [ERROR] COMM_DEPOSITED: No columns found for ORACLE_USER.COMM_DEPOSITED
# [145/471] [ERROR] COMM_DEPOSITED_STAGING: No columns found for ORACLE_USER.COMM_DEPOSITED_STAGING
# [146/471] [ERROR] COMM_INCLUDE: No columns found for ORACLE_USER.COMM_INCLUDE
# [147/471] [ERROR] COMPANY_SAVING_PLAN_CAP: No columns found for ORACLE_USER.COMPANY_SAVING_PLAN_CAP
# [148/471] [ERROR] COMPENS_APE_HURDLE: No columns found for ORACLE_USER.COMPENS_APE_HURDLE
# [149/471] [ERROR] COMPENS_AUTO_DED_EXTRACT: No columns found for ORACLE_USER.COMPENS_AUTO_DED_EXTRACT
# [150/471] [ERROR] COMPENS_CRED: No columns found for ORACLE_USER.COMPENS_CRED
# [151/471] [ERROR] COMPENS_CRED_INSTALLMENT: No columns found for ORACLE_USER.COMPENS_CRED_INSTALLMENT
# [152/471] [ERROR] COMPENS_CRED_MOVEMENT: No columns found for ORACLE_USER.COMPENS_CRED_MOVEMENT
# [153/471] [ERROR] COMPENS_CRED_PAYT: No columns found for ORACLE_USER.COMPENS_CRED_PAYT
# [154/471] [ERROR] COMPENS_CRED_RECURR_MOVEMNT: No columns found for ORACLE_USER.COMPENS_CRED_RECURR_MOVEMNT
# [155/471] [ERROR] COMPENS_DA_REQ: No columns found for ORACLE_USER.COMPENS_DA_REQ
# [156/471] [ERROR] COMPENS_DED: No columns found for ORACLE_USER.COMPENS_DED
# [157/471] [ERROR] COMPENS_DED_INSTALLMENT: No columns found for ORACLE_USER.COMPENS_DED_INSTALLMENT
# [158/471] [ERROR] COMPENS_DED_MOVEMENT: No columns found for ORACLE_USER.COMPENS_DED_MOVEMENT
# [159/471] [ERROR] COMPENS_DED_PAYT: No columns found for ORACLE_USER.COMPENS_DED_PAYT
# [160/471] [ERROR] COMPENS_DED_RECURR_MOVEMNT: No columns found for ORACLE_USER.COMPENS_DED_RECURR_MOVEMNT
# [161/471] [ERROR] COMPENS_MATRIX: No columns found for ORACLE_USER.COMPENS_MATRIX
# [162/471] [ERROR] COMPENS_MATRIX_ERROR_LOG: No columns found for ORACLE_USER.COMPENS_MATRIX_ERROR_LOG
# [163/471] [ERROR] COMPENS_MATRIX_FORRO: No columns found for ORACLE_USER.COMPENS_MATRIX_FORRO
# [164/471] [ERROR] COMPENS_MATRIX_HIST: No columns found for ORACLE_USER.COMPENS_MATRIX_HIST
# [165/471] [ERROR] COMPENS_MATRIX_IMPACT: No columns found for ORACLE_USER.COMPENS_MATRIX_IMPACT
# [166/471] [ERROR] COMPENS_MATRIX_NOT_INSERTED: No columns found for ORACLE_USER.COMPENS_MATRIX_NOT_INSERTED
# [167/471] [ERROR] COMPENS_MATRIX_SELLOUT: No columns found for ORACLE_USER.COMPENS_MATRIX_SELLOUT
# [168/471] [ERROR] COMPENS_MATRIX_TEMP: No columns found for ORACLE_USER.COMPENS_MATRIX_TEMP
# [169/471] [ERROR] COMPENS_MISC_CRED: No columns found for ORACLE_USER.COMPENS_MISC_CRED
# [170/471] [ERROR] COMPENS_MISC_DED: No columns found for ORACLE_USER.COMPENS_MISC_DED
# [171/471] [ERROR] COMPENS_RATE_COMPPROD: No columns found for ORACLE_USER.COMPENS_RATE_COMPPROD
# [172/471] [ERROR] COMPENS_RATE_GAO: No columns found for ORACLE_USER.COMPENS_RATE_GAO
# [173/471] [ERROR] COMPENS_RATE_IMDT_DLINE: No columns found for ORACLE_USER.COMPENS_RATE_IMDT_DLINE
# [174/471] [ERROR] COMPENS_RATE_LEADPROD: No columns found for ORACLE_USER.COMPENS_RATE_LEADPROD
# [175/471] [ERROR] COMPENS_RATE_NUM_FACTOR: No columns found for ORACLE_USER.COMPENS_RATE_NUM_FACTOR
# [176/471] [ERROR] COMPENS_RATE_PERSIST_GRP: No columns found for ORACLE_USER.COMPENS_RATE_PERSIST_GRP
# [177/471] [ERROR] COMPENS_RATE_QTR_NAP: No columns found for ORACLE_USER.COMPENS_RATE_QTR_NAP
# [178/471] [ERROR] COMPENS_RATE_RO: No columns found for ORACLE_USER.COMPENS_RATE_RO
# [179/471] [ERROR] COMPENS_RATE_TYPEPROD: No columns found for ORACLE_USER.COMPENS_RATE_TYPEPROD
# [180/471] [ERROR] COMPENS_RATE_YRSERVICE: No columns found for ORACLE_USER.COMPENS_RATE_YRSERVICE
# [181/471] [ERROR] COMPENS_RECURR_CRED: No columns found for ORACLE_USER.COMPENS_RECURR_CRED
# [182/471] [ERROR] COMPENS_RECURR_DED: No columns found for ORACLE_USER.COMPENS_RECURR_DED
# [183/471] [ERROR] COMPENS_SCHEME: No columns found for ORACLE_USER.COMPENS_SCHEME
# [184/471] [ERROR] COMPENS_TAB_AGENT: No columns found for ORACLE_USER.COMPENS_TAB_AGENT
# [185/471] [ERROR] COMPENS_TAB_AGENT_HISTORY: No columns found for ORACLE_USER.COMPENS_TAB_AGENT_HISTORY
# [186/471] [ERROR] COMPENS_TAB_ANNUAL_DTL: No columns found for ORACLE_USER.COMPENS_TAB_ANNUAL_DTL
# [187/471] [ERROR] COMPENS_TAB_ANNUAL_SUMM: No columns found for ORACLE_USER.COMPENS_TAB_ANNUAL_SUMM
# [188/471] [ERROR] COMPENS_TAB_BMUM_NAP: No columns found for ORACLE_USER.COMPENS_TAB_BMUM_NAP
# [189/471] [ERROR] COMPENS_TAB_MP: No columns found for ORACLE_USER.COMPENS_TAB_MP
# [190/471] [ERROR] COMPENS_TAB_NAP: No columns found for ORACLE_USER.COMPENS_TAB_NAP
# [191/471] [ERROR] COMPENS_TAB_NAP_ANN: No columns found for ORACLE_USER.COMPENS_TAB_NAP_ANN
# [192/471] [ERROR] COMPENS_TAB_QTOTAL: No columns found for ORACLE_USER.COMPENS_TAB_QTOTAL
# [193/471] [ERROR] COMPENS_TAB_RATES: No columns found for ORACLE_USER.COMPENS_TAB_RATES
# [194/471] [ERROR] COMPENS_TAB_RECRUIT: No columns found for ORACLE_USER.COMPENS_TAB_RECRUIT
# [195/471] [ERROR] COMPENS_TAB_SPARAM: No columns found for ORACLE_USER.COMPENS_TAB_SPARAM
# [196/471] [ERROR] COMPENS_TYPE: No columns found for ORACLE_USER.COMPENS_TYPE
# [197/471] [ERROR] COMPENS_TYPE_AGENT_TYPE: No columns found for ORACLE_USER.COMPENS_TYPE_AGENT_TYPE
# [198/471] [ERROR] COMPENS_TYPE_CATEGORY: No columns found for ORACLE_USER.COMPENS_TYPE_CATEGORY
# [199/471] [ERROR] COMPENS_TYPE_CLASS: No columns found for ORACLE_USER.COMPENS_TYPE_CLASS
# [200/471] [ERROR] COMPENS_TYPE_DIST_CHANNEL: No columns found for ORACLE_USER.COMPENS_TYPE_DIST_CHANNEL
# [201/471] [ERROR] COMPENS_TYPE_GRP: No columns found for ORACLE_USER.COMPENS_TYPE_GRP
# [202/471] [ERROR] COMPENS_TYPE_SCHEME: No columns found for ORACLE_USER.COMPENS_TYPE_SCHEME
# [203/471] [ERROR] COMPENS_YTDNAP_HURDLE: No columns found for ORACLE_USER.COMPENS_YTDNAP_HURDLE
# [204/471] [ERROR] CONTRACT_TYPE: No columns found for ORACLE_USER.CONTRACT_TYPE
# [205/471] [ERROR] CONTRACT_TYPE_ELIG: No columns found for ORACLE_USER.CONTRACT_TYPE_ELIG
# [206/471] [ERROR] CUT_OFF_SCHED: No columns found for ORACLE_USER.CUT_OFF_SCHED
# [207/471] [ERROR] CUT_OFF_SCHED_BCKP: No columns found for ORACLE_USER.CUT_OFF_SCHED_BCKP
# [208/471] [ERROR] DELETE_AGENT_MOVEMENT: No columns found for ORACLE_USER.DELETE_AGENT_MOVEMENT
# [209/471] [ERROR] DELIMITED_FILE_LIST: No columns found for ORACLE_USER.DELIMITED_FILE_LIST
# [210/471] [ERROR] DELIMITED_FILE_VALIDATION: No columns found for ORACLE_USER.DELIMITED_FILE_VALIDATION
# [211/471] [ERROR] DEPARTMENT: No columns found for ORACLE_USER.DEPARTMENT
# [212/471] [ERROR] DEPT_SERVICE: No columns found for ORACLE_USER.DEPT_SERVICE
# [213/471] [ERROR] DISBURSING_BANK: No columns found for ORACLE_USER.DISBURSING_BANK
# [214/471] [ERROR] DISTRIBUTION_CHANNEL: No columns found for ORACLE_USER.DISTRIBUTION_CHANNEL
# [215/471] [ERROR] DMPATPNS: No columns found for ORACLE_USER.DMPATPNS
# [216/471] [ERROR] DOMAIN: No columns found for ORACLE_USER.DOMAIN
# [217/471] [ERROR] EXTRACT_LIST: No columns found for ORACLE_USER.EXTRACT_LIST
# [218/471] [ERROR] EXTRACT_LIST_TEST: No columns found for ORACLE_USER.EXTRACT_LIST_TEST
# [219/471] [ERROR] EXTRACT_PROCESS_ERROR: No columns found for ORACLE_USER.EXTRACT_PROCESS_ERROR
# [220/471] [ERROR] FEATURE_CONTROL: No columns found for ORACLE_USER.FEATURE_CONTROL
# [221/471] [ERROR] FIN_MANUAL_PAYMENT: No columns found for ORACLE_USER.FIN_MANUAL_PAYMENT
# [222/471] [ERROR] FIN_PAYOUT_SUMMARY: No columns found for ORACLE_USER.FIN_PAYOUT_SUMMARY
# [223/471] [ERROR] FROM_SIRWILL: No columns found for ORACLE_USER.FROM_SIRWILL
# [224/471] [ERROR] GET_MANPOWER_REQUEST: No columns found for ORACLE_USER.GET_MANPOWER_REQUEST
# [225/471] [ERROR] GL_ACCT: No columns found for ORACLE_USER.GL_ACCT
# [226/471] [ERROR] GL_TRAN_DTL: No columns found for ORACLE_USER.GL_TRAN_DTL
# [227/471] [ERROR] GL_TRAN_DTL_HIST: No columns found for ORACLE_USER.GL_TRAN_DTL_HIST
# [228/471] [ERROR] GL_TRAN_DTL_POLREP: No columns found for ORACLE_USER.GL_TRAN_DTL_POLREP
# [229/471] [ERROR] GL_TRAN_DTL_RPT: No columns found for ORACLE_USER.GL_TRAN_DTL_RPT
# [230/471] [ERROR] GL_TRAN_DTL_TERMINATED: No columns found for ORACLE_USER.GL_TRAN_DTL_TERMINATED
# [231/471] [ERROR] GL_TRAN_DTL_TPD: No columns found for ORACLE_USER.GL_TRAN_DTL_TPD
# [232/471] [ERROR] GL_TRAN_SUMMARY: No columns found for ORACLE_USER.GL_TRAN_SUMMARY
# [233/471] [ERROR] GL_TRAN_SUMMARY_BKP: No columns found for ORACLE_USER.GL_TRAN_SUMMARY_BKP
# [234/471] [ERROR] GL_TRAN_SUMMARY_POLREP: No columns found for ORACLE_USER.GL_TRAN_SUMMARY_POLREP
# [235/471] [ERROR] GMI_TEST: No columns found for ORACLE_USER.GMI_TEST
# [236/471] [ERROR] GROSS_INCOME: No columns found for ORACLE_USER.GROSS_INCOME
# [237/471] [ERROR] GROSS_YTD: No columns found for ORACLE_USER.GROSS_YTD
# [238/471] [ERROR] GROUP_SCHED: No columns found for ORACLE_USER.GROUP_SCHED
# [239/471] [ERROR] HASH_SUMMARY: No columns found for ORACLE_USER.HASH_SUMMARY
# [240/471] [ERROR] HASH_SUMMARY_HISTORY: No columns found for ORACLE_USER.HASH_SUMMARY_HISTORY
# [241/471] [ERROR] HASH_SUMMARY_OPTIMIZATION: No columns found for ORACLE_USER.HASH_SUMMARY_OPTIMIZATION
# [242/471] [ERROR] HISTORICAL_DATA: No columns found for ORACLE_USER.HISTORICAL_DATA
# [243/471] [ERROR] HYPERLINK: No columns found for ORACLE_USER.HYPERLINK
# [244/471] [ERROR] HYPERLINK_HIERARCHY: No columns found for ORACLE_USER.HYPERLINK_HIERARCHY
# [245/471] [ERROR] INORGANIC_ADJUSTMENTS: No columns found for ORACLE_USER.INORGANIC_ADJUSTMENTS
# [246/471] [ERROR] INORGANIC_DISBURSE: No columns found for ORACLE_USER.INORGANIC_DISBURSE
# [247/471] [ERROR] INORGANIC_ENROLLEES: No columns found for ORACLE_USER.INORGANIC_ENROLLEES
# [248/471] [ERROR] INORGANIC_MP_DTL: No columns found for ORACLE_USER.INORGANIC_MP_DTL
# [249/471] [ERROR] INORGANIC_NAP_DTL: No columns found for ORACLE_USER.INORGANIC_NAP_DTL
# [250/471] [ERROR] INORGANIC_PACKAGES: No columns found for ORACLE_USER.INORGANIC_PACKAGES
# [251/471] [ERROR] INORGANIC_QUALIFIERS: No columns found for ORACLE_USER.INORGANIC_QUALIFIERS
# [252/471] [ERROR] INORGANIC_TARGETS: No columns found for ORACLE_USER.INORGANIC_TARGETS
# [253/471] [ERROR] INORGANI_ORC: No columns found for ORACLE_USER.INORGANI_ORC
# [254/471] [ERROR] JAVA: No columns found for ORACLE_USER.JAVA
# [255/471] [ERROR] JAVA_CLASS: No columns found for ORACLE_USER.JAVA_CLASS
# [256/471] [ERROR] KILL_SWITCH: No columns found for ORACLE_USER.KILL_SWITCH
# [257/471] [ERROR] LETTER_OF_INSTRUCTION: No columns found for ORACLE_USER.LETTER_OF_INSTRUCTION
# [258/471] [ERROR] LVL_UP_QUALIFIER: No columns found for ORACLE_USER.LVL_UP_QUALIFIER
# [259/471] [ERROR] MANPOWER_OF: No columns found for ORACLE_USER.MANPOWER_OF
# [260/471] [ERROR] MANPOWER_SOURCE: No columns found for ORACLE_USER.MANPOWER_SOURCE
# [261/471] [ERROR] MANUAL_PAYMENT: No columns found for ORACLE_USER.MANUAL_PAYMENT
# [262/471] [ERROR] MANUAL_PAYMENT_BACK: No columns found for ORACLE_USER.MANUAL_PAYMENT_BACK
# [263/471] [ERROR] MD_APPLICATIONS: No columns found for ORACLE_USER.MD_APPLICATIONS
# [264/471] [ERROR] MIGRATION_AGENT_TIN_NO: No columns found for ORACLE_USER.MIGRATION_AGENT_TIN_NO
# [265/471] [ERROR] MIGRATION_FINAL_TAB: No columns found for ORACLE_USER.MIGRATION_FINAL_TAB
# [266/471] [ERROR] MIGRATION_PAYOUT_DTL: No columns found for ORACLE_USER.MIGRATION_PAYOUT_DTL
# [267/471] [ERROR] MIGRATION_PAYOUT_SUMMARY: No columns found for ORACLE_USER.MIGRATION_PAYOUT_SUMMARY
# [268/471] [ERROR] MIGRATION_PREMIUM_RCVD: No columns found for ORACLE_USER.MIGRATION_PREMIUM_RCVD
# [269/471] [ERROR] MODEL_TYPE: No columns found for ORACLE_USER.MODEL_TYPE
# [270/471] [ERROR] MO_COMPENS_MATRIX_ORC: No columns found for ORACLE_USER.MO_COMPENS_MATRIX_ORC
# [271/471] [ERROR] NEW_AGENTS: No columns found for ORACLE_USER.NEW_AGENTS
# [272/471] [ERROR] NEW_AGENTS_TEST: No columns found for ORACLE_USER.NEW_AGENTS_TEST
# [273/471] [ERROR] NOMANAGER: No columns found for ORACLE_USER.NOMANAGER
# [274/471] [ERROR] ORC_FYO: No columns found for ORACLE_USER.ORC_FYO
# [275/471] [ERROR] ORPHAN_SYO: No columns found for ORACLE_USER.ORPHAN_SYO
# [276/471] [ERROR] PAYOUT_DTL: No columns found for ORACLE_USER.PAYOUT_DTL
# [277/471] [ERROR] PAYOUT_SUMMARY: No columns found for ORACLE_USER.PAYOUT_SUMMARY
# [278/471] [ERROR] PAYROLL_SUMMARY: No columns found for ORACLE_USER.PAYROLL_SUMMARY
# [279/471] [ERROR] PERSISTENCY: No columns found for ORACLE_USER.PERSISTENCY
# [280/471] [ERROR] PLAN: No columns found for ORACLE_USER.PLAN
# [281/471] [ERROR] PO: No columns found for ORACLE_USER.PO
# [282/471] [ERROR] POLICY: No columns found for ORACLE_USER.POLICY
# [283/471] [ERROR] POLICY_BREAKAWAY: No columns found for ORACLE_USER.POLICY_BREAKAWAY
# [284/471] [ERROR] POLICY_BREAKAWAY_TEST: No columns found for ORACLE_USER.POLICY_BREAKAWAY_TEST
# [285/471] [ERROR] POLICY_DELIVERY_RECEIPT: No columns found for ORACLE_USER.POLICY_DELIVERY_RECEIPT
# [286/471] [ERROR] POLICY_EXTENSION: No columns found for ORACLE_USER.POLICY_EXTENSION
# [287/471] [ERROR] POLICY_REPLACEMENT: No columns found for ORACLE_USER.POLICY_REPLACEMENT
# [288/471] [ERROR] POLICY_REPLACEMENT_BCK: No columns found for ORACLE_USER.POLICY_REPLACEMENT_BCK
# [289/471] [ERROR] POLICY_REPLACEMENT_REF: No columns found for ORACLE_USER.POLICY_REPLACEMENT_REF
# [290/471] [ERROR] POLICY_RIDER: No columns found for ORACLE_USER.POLICY_RIDER
# [291/471] [ERROR] PO_REL: No columns found for ORACLE_USER.PO_REL
# [292/471] [ERROR] PREMIUM_RCVD: No columns found for ORACLE_USER.PREMIUM_RCVD
# [293/471] [ERROR] PROCESS: No columns found for ORACLE_USER.PROCESS
# [294/471] [ERROR] PROCESS_DEPENDENCY: No columns found for ORACLE_USER.PROCESS_DEPENDENCY
# [295/471] [ERROR] PROCESS_DURATION: No columns found for ORACLE_USER.PROCESS_DURATION
# [296/471] [ERROR] PROCESS_ERROR_LOG: No columns found for ORACLE_USER.PROCESS_ERROR_LOG
# [297/471] [ERROR] PROCESS_LOG: No columns found for ORACLE_USER.PROCESS_LOG
# [298/471] [ERROR] PRODFIX_AGENT_SCHED_DEDUCTION: No columns found for ORACLE_USER.PRODFIX_AGENT_SCHED_DEDUCTION
# [299/471] [ERROR] PRODUCTION: No columns found for ORACLE_USER.PRODUCTION
# [300/471] [ERROR] PRODUCTION_BACKUP: No columns found for ORACLE_USER.PRODUCTION_BACKUP
# [301/471] [ERROR] PRODUCTION_SUMMARY: No columns found for ORACLE_USER.PRODUCTION_SUMMARY
# [302/471] [ERROR] PRODUCTION_UNIT: No columns found for ORACLE_USER.PRODUCTION_UNIT
# [303/471] [ERROR] PRUACE_ADJUSTMENTS: No columns found for ORACLE_USER.PRUACE_ADJUSTMENTS
# [304/471] [ERROR] PRUACE_CC_DTL: No columns found for ORACLE_USER.PRUACE_CC_DTL
# [305/471] [ERROR] PRUACE_DISBURSE: No columns found for ORACLE_USER.PRUACE_DISBURSE
# [306/471] [ERROR] PRUACE_DISBURSE_BK: No columns found for ORACLE_USER.PRUACE_DISBURSE_BK
# [307/471] [ERROR] PRUACE_ENROLLEES: No columns found for ORACLE_USER.PRUACE_ENROLLEES
# [308/471] [ERROR] PRUACE_NAP_DTL: No columns found for ORACLE_USER.PRUACE_NAP_DTL
# [309/471] [ERROR] PRUACE_PACKAGES: No columns found for ORACLE_USER.PRUACE_PACKAGES
# [310/471] [ERROR] PRUACE_QUALIFIERS: No columns found for ORACLE_USER.PRUACE_QUALIFIERS
# [311/471] [ERROR] PRUACE_TARGETS: No columns found for ORACLE_USER.PRUACE_TARGETS
# [312/471] [ERROR] QUALITY_FACTOR: No columns found for ORACLE_USER.QUALITY_FACTOR
# [313/471] [ERROR] REF_SCHED: No columns found for ORACLE_USER.REF_SCHED
# [314/471] [ERROR] REPORT_UI: No columns found for ORACLE_USER.REPORT_UI
# [315/471] [ERROR] REVERSAL_CODE: No columns found for ORACLE_USER.REVERSAL_CODE
# [316/471] [ERROR] RIMON_AGENT: No columns found for ORACLE_USER.RIMON_AGENT
# [317/471] [ERROR] RIMON_AGENT_DOWNLINES: No columns found for ORACLE_USER.RIMON_AGENT_DOWNLINES
# [318/471] [ERROR] RIMON_AGENT_RELATIONSHIP: No columns found for ORACLE_USER.RIMON_AGENT_RELATIONSHIP
# [319/471] [ERROR] RIMON_AGENT_TAGS: No columns found for ORACLE_USER.RIMON_AGENT_TAGS
# [320/471] [ERROR] RIMON_FEATURE_CONTROL: No columns found for ORACLE_USER.RIMON_FEATURE_CONTROL
# [321/471] [ERROR] RIMON_HIERARCHY_TAB: No columns found for ORACLE_USER.RIMON_HIERARCHY_TAB
# [322/471] [ERROR] RIMON_SOA_SUMMARY: No columns found for ORACLE_USER.RIMON_SOA_SUMMARY
# [323/471] [ERROR] RMA_CONTRACT_TYPE: No columns found for ORACLE_USER.RMA_CONTRACT_TYPE
# [324/471] [ERROR] RMA_NEW_AGENTS: No columns found for ORACLE_USER.RMA_NEW_AGENTS
# [325/471] [ERROR] RMA_TAG_TYPE: No columns found for ORACLE_USER.RMA_TAG_TYPE
# [326/471] [ERROR] ROLE: No columns found for ORACLE_USER.ROLE
# [327/471] [ERROR] ROLE_SERVICE: No columns found for ORACLE_USER.ROLE_SERVICE
# [328/471] [ERROR] RO_TEMP_TABLE: No columns found for ORACLE_USER.RO_TEMP_TABLE
# [329/471] [ERROR] SAVINGSFUND_STG: No columns found for ORACLE_USER.SAVINGSFUND_STG
# [330/471] [ERROR] SBS_BASE_DATA: No columns found for ORACLE_USER.SBS_BASE_DATA
# [331/471] [ERROR] SBS_BASE_DATA_KOA: No columns found for ORACLE_USER.SBS_BASE_DATA_KOA
# [332/471] [ERROR] SELLOUT_AGREEMENTS: No columns found for ORACLE_USER.SELLOUT_AGREEMENTS
# [333/471] [ERROR] SELLOUT_ENROLLEES: No columns found for ORACLE_USER.SELLOUT_ENROLLEES
# [334/471] [ERROR] SERVICE: No columns found for ORACLE_USER.SERVICE
# [335/471] [ERROR] SIGNATORY: No columns found for ORACLE_USER.SIGNATORY
# [336/471] [ERROR] SOA_BALANCE_FORWARDED: No columns found for ORACLE_USER.SOA_BALANCE_FORWARDED
# [337/471] [ERROR] SOA_BALANCE_FORWARDED_BK: No columns found for ORACLE_USER.SOA_BALANCE_FORWARDED_BK
# [338/471] [ERROR] SOA_BONUS_DTL: No columns found for ORACLE_USER.SOA_BONUS_DTL
# [339/471] [ERROR] SOA_BONUS_DTL_BK: No columns found for ORACLE_USER.SOA_BONUS_DTL_BK
# [340/471] [ERROR] SOA_COMMISSION_DTL: No columns found for ORACLE_USER.SOA_COMMISSION_DTL
# [341/471] [ERROR] SOA_COMMISSION_DTL_BK: No columns found for ORACLE_USER.SOA_COMMISSION_DTL_BK
# [342/471] [ERROR] SOA_CRED_TO_BPI: No columns found for ORACLE_USER.SOA_CRED_TO_BPI
# [343/471] [ERROR] SOA_CRED_TO_BPI_BK: No columns found for ORACLE_USER.SOA_CRED_TO_BPI_BK
# [344/471] [ERROR] SOA_GA_OVERRIDE_DTL: No columns found for ORACLE_USER.SOA_GA_OVERRIDE_DTL
# [345/471] [ERROR] SOA_GA_OVERRIDE_DTL_BK: No columns found for ORACLE_USER.SOA_GA_OVERRIDE_DTL_BK
# [346/471] [ERROR] SOA_HOLD_BONUS_DTL: No columns found for ORACLE_USER.SOA_HOLD_BONUS_DTL
# [347/471] [ERROR] SOA_HOLD_BONUS_DTL_BK: No columns found for ORACLE_USER.SOA_HOLD_BONUS_DTL_BK
# [348/471] [ERROR] SOA_HOLD_COMMISSION_DTL: No columns found for ORACLE_USER.SOA_HOLD_COMMISSION_DTL
# [349/471] [ERROR] SOA_HOLD_COMMISSION_DTL_BK: No columns found for ORACLE_USER.SOA_HOLD_COMMISSION_DTL_BK
# [350/471] [ERROR] SOA_HOLD_GA_OVERRIDE_DTL: No columns found for ORACLE_USER.SOA_HOLD_GA_OVERRIDE_DTL
# [351/471] [ERROR] SOA_HOLD_GA_OVERRIDE_DTL_BK: No columns found for ORACLE_USER.SOA_HOLD_GA_OVERRIDE_DTL_BK
# [352/471] [ERROR] SOA_HOLD_OVERRIDE_DTL: No columns found for ORACLE_USER.SOA_HOLD_OVERRIDE_DTL
# [353/471] [ERROR] SOA_HOLD_OVERRIDE_DTL_BK: No columns found for ORACLE_USER.SOA_HOLD_OVERRIDE_DTL_BK
# [354/471] [ERROR] SOA_HOLD_OVERRIDE_SELLOUT: No columns found for ORACLE_USER.SOA_HOLD_OVERRIDE_SELLOUT
# [355/471] [ERROR] SOA_HOLD_OVERRIDE_XSELLOUT: No columns found for ORACLE_USER.SOA_HOLD_OVERRIDE_XSELLOUT
# [356/471] [ERROR] SOA_LIST: No columns found for ORACLE_USER.SOA_LIST
# [357/471] [ERROR] SOA_LISTBACKUP: No columns found for ORACLE_USER.SOA_LISTBACKUP
# [358/471] [ERROR] SOA_LIST_BK: No columns found for ORACLE_USER.SOA_LIST_BK
# [359/471] [ERROR] SOA_LIST_ORIG: No columns found for ORACLE_USER.SOA_LIST_ORIG
# [360/471] [ERROR] SOA_MISC_ADJUSTMENTS: No columns found for ORACLE_USER.SOA_MISC_ADJUSTMENTS
# [361/471] [ERROR] SOA_MISC_ADJUSTMENTS_BK: No columns found for ORACLE_USER.SOA_MISC_ADJUSTMENTS_BK
# [362/471] [ERROR] SOA_MISC_CR_DTL: No columns found for ORACLE_USER.SOA_MISC_CR_DTL
# [363/471] [ERROR] SOA_MISC_CR_DTL_BK: No columns found for ORACLE_USER.SOA_MISC_CR_DTL_BK
# [364/471] [ERROR] SOA_MISC_DR_DTL: No columns found for ORACLE_USER.SOA_MISC_DR_DTL
# [365/471] [ERROR] SOA_MISC_DR_DTL_BK: No columns found for ORACLE_USER.SOA_MISC_DR_DTL_BK
# [366/471] [ERROR] SOA_MULTIPLE_SUSPENSION: No columns found for ORACLE_USER.SOA_MULTIPLE_SUSPENSION
# [367/471] [ERROR] SOA_MULTIPLE_SUSPENSION_BK: No columns found for ORACLE_USER.SOA_MULTIPLE_SUSPENSION_BK
# [368/471] [ERROR] SOA_NOT_DEDUCTED: No columns found for ORACLE_USER.SOA_NOT_DEDUCTED
# [369/471] [ERROR] SOA_NOT_DEDUCTED_BK: No columns found for ORACLE_USER.SOA_NOT_DEDUCTED_BK
# [370/471] [ERROR] SOA_OVERRIDE_DTL: No columns found for ORACLE_USER.SOA_OVERRIDE_DTL
# [371/471] [ERROR] SOA_OVERRIDE_DTL_BK: No columns found for ORACLE_USER.SOA_OVERRIDE_DTL_BK
# [372/471] [ERROR] SOA_OVERRIDE_SELLOUT: No columns found for ORACLE_USER.SOA_OVERRIDE_SELLOUT
# [373/471] [ERROR] SOA_OVERRIDE_XSELLOUT: No columns found for ORACLE_USER.SOA_OVERRIDE_XSELLOUT
# [374/471] [ERROR] SOA_POLICY_REVERSAL: No columns found for ORACLE_USER.SOA_POLICY_REVERSAL
# [375/471] [ERROR] SOA_POLICY_REVERSAL_BK: No columns found for ORACLE_USER.SOA_POLICY_REVERSAL_BK
# [376/471] [ERROR] SOA_POLREP: No columns found for ORACLE_USER.SOA_POLREP
# [377/471] [ERROR] SOA_POLREP_BK: No columns found for ORACLE_USER.SOA_POLREP_BK
# [378/471] [ERROR] SOA_SUMMARY: No columns found for ORACLE_USER.SOA_SUMMARY
# [379/471] [ERROR] SOA_TAB_PARAM: No columns found for ORACLE_USER.SOA_TAB_PARAM
# [380/471] [ERROR] SOA_TPD_POLREP: No columns found for ORACLE_USER.SOA_TPD_POLREP
# [381/471] [ERROR] SOA_TPD_POLREPREF: No columns found for ORACLE_USER.SOA_TPD_POLREPREF
# [382/471] [ERROR] SOA_TPD_SUMM: No columns found for ORACLE_USER.SOA_TPD_SUMM
# [383/471] [ERROR] SOA_YTD: No columns found for ORACLE_USER.SOA_YTD
# [384/471] [ERROR] SOA_YTD_BK: No columns found for ORACLE_USER.SOA_YTD_BK
# [385/471] [ERROR] SPLIT_COMMISSION: No columns found for ORACLE_USER.SPLIT_COMMISSION
# [386/471] [ERROR] SUMMARY_REPORTS_CURRENT: No columns found for ORACLE_USER.SUMMARY_REPORTS_CURRENT
# [387/471] [ERROR] SUMMARY_REPORTS_SAVINGS: No columns found for ORACLE_USER.SUMMARY_REPORTS_SAVINGS
# [388/471] [ERROR] SUPER_EXTRACT_DTL: No columns found for ORACLE_USER.SUPER_EXTRACT_DTL
# [389/471] [ERROR] SUPER_EXTRACT_SUMM: No columns found for ORACLE_USER.SUPER_EXTRACT_SUMM
# [390/471] [ERROR] SUSPENDED_PAYOUT: No columns found for ORACLE_USER.SUSPENDED_PAYOUT
# [391/471] [ERROR] SUSPENSION_MONITORING: No columns found for ORACLE_USER.SUSPENSION_MONITORING
# [392/471] [ERROR] SYS_AUDIT_TRAIL: No columns found for ORACLE_USER.SYS_AUDIT_TRAIL
# [393/471] [ERROR] SYS_ERROR: No columns found for ORACLE_USER.SYS_ERROR
# [394/471] [ERROR] SYS_PARAMETER: No columns found for ORACLE_USER.SYS_PARAMETER
# [395/471] [ERROR] SYS_REF: No columns found for ORACLE_USER.SYS_REF
# [396/471] [ERROR] SYS_REF_TABLE: No columns found for ORACLE_USER.SYS_REF_TABLE
# [397/471] [ERROR] SYS_USER: No columns found for ORACLE_USER.SYS_USER
# [398/471] [ERROR] TAB_CANCELLATIONS: No columns found for ORACLE_USER.TAB_CANCELLATIONS
# [399/471] [ERROR] TAB_REVERSAL: No columns found for ORACLE_USER.TAB_REVERSAL
# [400/471] [ERROR] TAG_TYPE: No columns found for ORACLE_USER.TAG_TYPE
# [401/471] [ERROR] TAX: No columns found for ORACLE_USER.TAX
# [402/471] [ERROR] TAX_UPGRADE: No columns found for ORACLE_USER.TAX_UPGRADE
# [403/471] [ERROR] TEMP_AGENT_CODEERROR: No columns found for ORACLE_USER.TEMP_AGENT_CODEERROR
# [404/471] [ERROR] TEMP_ERROR_FINDER: No columns found for ORACLE_USER.TEMP_ERROR_FINDER
# [405/471] [ERROR] TEMP_JUMERROR: No columns found for ORACLE_USER.TEMP_JUMERROR
# [406/471] [ERROR] TEMP_LR_HIERARCHY: No columns found for ORACLE_USER.TEMP_LR_HIERARCHY
# [407/471] [ERROR] TEMP_TABLE: No columns found for ORACLE_USER.TEMP_TABLE
# [408/471] [ERROR] TEMP_TRANNO: No columns found for ORACLE_USER.TEMP_TRANNO
# [409/471] [ERROR] TEST: No columns found for ORACLE_USER.TEST
# [410/471] [ERROR] TEST_AGENTS: No columns found for ORACLE_USER.TEST_AGENTS
# [411/471] [ERROR] TEST_AGENT_TAGS: No columns found for ORACLE_USER.TEST_AGENT_TAGS
# [412/471] [ERROR] TMP_AGU_CALLERS: No columns found for ORACLE_USER.TMP_AGU_CALLERS
# [413/471] [ERROR] TMP_AGU_RUNTIME_AUDIT: No columns found for ORACLE_USER.TMP_AGU_RUNTIME_AUDIT
# [414/471] [ERROR] TMP_UPLINE_COMPARE: No columns found for ORACLE_USER.TMP_UPLINE_COMPARE
# [415/471] [ERROR] TOAD_PLAN_SQL: No columns found for ORACLE_USER.TOAD_PLAN_SQL
# [416/471] [ERROR] TOAD_PLAN_TABLE: No columns found for ORACLE_USER.TOAD_PLAN_TABLE
# [417/471] [ERROR] TRANSACTION: No columns found for ORACLE_USER.TRANSACTION
# [418/471] [ERROR] TRANSACTION_OLD: No columns found for ORACLE_USER.TRANSACTION_OLD
# [419/471] [ERROR] UPLINE_TEST_CASES: No columns found for ORACLE_USER.UPLINE_TEST_CASES
# [420/471] [ERROR] UPLINE_TEST_DIFFS: No columns found for ORACLE_USER.UPLINE_TEST_DIFFS
# [421/471] [ERROR] UPLINE_TEST_RESULTS: No columns found for ORACLE_USER.UPLINE_TEST_RESULTS
# [422/471] [ERROR] UPLINE_TEST_RESULTS_MOD: No columns found for ORACLE_USER.UPLINE_TEST_RESULTS_MOD
# [423/471] [ERROR] UPLINE_TEST_RESULTS_ORIG: No columns found for ORACLE_USER.UPLINE_TEST_RESULTS_ORIG
# [424/471] [ERROR] USER_OBJECTS_RIMON: No columns found for ORACLE_USER.USER_OBJECTS_RIMON
# [425/471] [ERROR] XAGENTASSGN_HIST: No columns found for ORACLE_USER.XAGENTASSGN_HIST
# [426/471] [ERROR] XAGENTASSGN_STAGING: No columns found for ORACLE_USER.XAGENTASSGN_STAGING
# [427/471] [ERROR] XAGENTDEDUCTION_HIST: No columns found for ORACLE_USER.XAGENTDEDUCTION_HIST
# [428/471] [ERROR] XAGENTDEDUCTION_STAGING: No columns found for ORACLE_USER.XAGENTDEDUCTION_STAGING
# [429/471] [ERROR] XAGENTPERSISTENCY_HIST: No columns found for ORACLE_USER.XAGENTPERSISTENCY_HIST
# [430/471] [ERROR] XAGENTPERSISTENCY_STAGING: No columns found for ORACLE_USER.XAGENTPERSISTENCY_STAGING
# [431/471] [ERROR] XAPTD: No columns found for ORACLE_USER.XAPTD
# [432/471] [ERROR] XBOUNCHEDCHK_HIST: No columns found for ORACLE_USER.XBOUNCHEDCHK_HIST
# [433/471] [ERROR] XBOUNCHEDCHK_STAGING: No columns found for ORACLE_USER.XBOUNCHEDCHK_STAGING
# [434/471] [ERROR] XCHEQUERCPT_HIST: No columns found for ORACLE_USER.XCHEQUERCPT_HIST
# [435/471] [ERROR] XCHEQUERCPT_STAGING: No columns found for ORACLE_USER.XCHEQUERCPT_STAGING
# [436/471] [ERROR] XCLIENT_HIST: No columns found for ORACLE_USER.XCLIENT_HIST
# [437/471] [ERROR] XCLIENT_STAGING: No columns found for ORACLE_USER.XCLIENT_STAGING
# [438/471] [ERROR] XCOMMISSION_HIST: No columns found for ORACLE_USER.XCOMMISSION_HIST
# [439/471] [ERROR] XCOMMISSION_STAGING: No columns found for ORACLE_USER.XCOMMISSION_STAGING
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File src/oracledb/impl/thin/connection.pyx:421, in oracledb.thin_impl.ThinConnImpl._connect_with_address()
# --> 421 'Could not get source, probably due dynamically evaluated source code.'
#
# File src/oracledb/impl/thin/protocol.pyx:288, in oracledb.thin_impl.Protocol._connect_phase_one()
# --> 288 'Could not get source, probably due dynamically evaluated source code.'
#
# File src/oracledb/impl/thin/protocol.pyx:470, in oracledb.thin_impl.Protocol._process_message()
# --> 470 'Could not get source, probably due dynamically evaluated source code.'
#
# File src/oracledb/impl/thin/protocol.pyx:446, in oracledb.thin_impl.Protocol._process_message()
# --> 446 'Could not get source, probably due dynamically evaluated source code.'
#
# File src/oracledb/impl/thin/messages/connect.pyx:102, in oracledb.thin_impl.ConnectMessage.process()
# --> 102 'Could not get source, probably due dynamically evaluated source code.'
#
# File /opt/conda/lib/python3.13/site-packages/oracledb/errors.py:199, in _raise_err(error_num, context_error_message, cause, **args)
#     198 error = _create_err(error_num, context_error_message, cause, **args)
# --> 199 raise error.exc_type(error) from cause
#
# OperationalError: DPY-6000: Listener refused connection. (Similar to ORA-12516)
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 results = migrate_all_tables()
#
# Cell In[10], line 111, in migrate_all_tables()
#     107                 raise RuntimeError(f"{len(results['failed'])} table(s) failed to migrate")
#     108         return results
#     109     finally:
#     110         setup_ora.close()
# --> 111         setup_pg.close()
#
# File /opt/conda/lib/python3.13/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/conda/lib/python3.13/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /opt/conda/lib/python3.13/concurrent/futures/thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# Cell In[10], line 22, in migrate_one_table(table_name)
#      18     Full per-table pipeline on dedicated connections (safe to run in a worker thread).
#      19     Returns (table_name, ok: bool, error: str | None, seconds: float).
#      20     """
#      21     t0 = datetime.datetime.now()
# ---> 22     ora_conn = get_oracle_connection()
#      23     pg_conn = get_postgres_connection()
#      24     try:
#      25         ddl_path, csv_path = dump_oracle_table(ora_conn, table_name)        # STEP 1
#
# Cell In[3], line 13, in get_oracle_connection()
#       9     elif ORACLE_SID:
#      10         dsn = oracledb.makedsn(ORACLE_HOST, ORACLE_PORT, sid=ORACLE_SID)
#      11     else:
#      12         raise ValueError("Either ORACLE_SERVICE_NAME or ORACLE_SID must be set.")
# ---> 13     return oracledb.connect(user=ORACLE_USER, password=ORACLE_PASSWORD, dsn=dsn)
#
# File /opt/conda/lib/python3.13/site-packages/oracledb/connection.py:1768, in _connection_factory.<locals>.connect(dsn, pool, pool_alias, conn_class, params, **kwargs)
#    1766     message = "pool must be an instance of oracledb.ConnectionPool"
#    1767     raise TypeError(message)
# -> 1768 return conn_class(dsn=dsn, pool=pool, params=params, **kwargs)
#
# File /opt/conda/lib/python3.13/site-packages/oracledb/connection.py:892, in Connection.__init__(self, dsn, pool, params, **kwargs)
#     890     else:
#     891         impl = thin_impl.ThinConnImpl(dsn, params_impl)
# --> 892         impl.connect(params_impl)
#     893 else:
#     894     impl = thick_impl.ThickConnImpl(dsn, params_impl)
#
# File src/oracledb/impl/thin/connection.pyx:544, in oracledb.thin_impl.ThinConnImpl.connect()
# --> 544 'Could not get source, probably due dynamically evaluated source code.'
#
# File src/oracledb/impl/thin/connection.pyx:540, in oracledb.thin_impl.ThinConnImpl.connect()
# --> 540 'Could not get source, probably due dynamically evaluated source code.'
#
# File src/oracledb/impl/thin/connection.pyx:482, in oracledb.thin_impl.ThinConnImpl._connect_with_params()
# --> 482 'Could not get source, probably due dynamically evaluated source code.'
#
# File src/oracledb/impl/thin/connection.pyx:463, in oracledb.thin_impl.ThinConnImpl._connect_with_description()
# --> 463 'Could not get source, probably due dynamically evaluated source code.'
#
# File src/oracledb/impl/thin/connection.pyx:425, in oracledb.thin_impl.ThinConnImpl._connect_with_address()
# --> 425 'Could not get source, probably due dynamically evaluated source code.'
#
# File /opt/conda/lib/python3.13/site-packages/oracledb/errors.py:199, in _raise_err(error_num, context_error_message, cause, **args)
#     194 """
#     195 Raises a driver specific exception from the specified error number and
#     196 supplied arguments.
#     197 """
#     198 error = _create_err(error_num, context_error_message, cause, **args)
# --> 199 raise error.exc_type(error) from cause
#
# OperationalError: DPY-6005: cannot connect to database (CONNECTION_ID=COdcsgfNJS1bxPWKOgQ/Xg==).
# DPY-6000: Listener refused connection. (Similar to ORA-12516)

# %% [markdown]
# ## 8. (Optional) Summary as a Spark DataFrame for easy inspection

# %%
summary_rows = (
    [(t, "OK", "") for t in results["ok"]]
    + [(t, "FAILED", err) for t, err in results["failed"]]
)
summary_df = spark.createDataFrame(summary_rows, ["table_name", "status", "error"])
display(summary_df)
